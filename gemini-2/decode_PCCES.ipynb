# %%
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None)

import numpy as np

colnames = ['Unnamed:0', '章碼', '章名', '6碼', '6碼名稱', '7碼', '7碼名稱', '8碼', '8碼名稱', '9碼',
       '9碼名稱', '10碼', '10碼名稱', '備註']

def get_field_code(df):
    field = df[['章碼', '章名']]
    code = '{:05}'.format(int(field['章碼'][0]))
    name = field['章名'][0]
    return code, name

def get_culumns(df):
    column = []
    for i in range(6, 11):
        field = df[f'{i}碼名稱']
        column.append(field[0])
    return column

def parse_code(code):
    if isinstance(code, np.floating) or isinstance(code, float):
        return str(int(code))
    return str(code)

def append_items(df, code, lis):
    for i in range(6, 11):
        field = df.iloc[1:][[f'{i}碼',f'{i}碼名稱']]
        field = field[pd.notna(field[f'{i}碼'])]
        field[f'{i}碼名稱'] = field[f'{i}碼名稱'].fillna('')
        for j, row in field.iterrows():
            lis.append([code, j, i, parse_code(row[f'{i}碼']), row[f'{i}碼名稱']])



def get_group(df, th):
    field = df[[f'{th}碼', f'{th}碼名稱']]
    group_info = []
    continue_lis = []
    for i in range(len(field)):
        if i in continue_lis:
            continue
        if pd.notna(field.iloc[i][f'{th}碼']):
            start_idx = i
            group = []
            idx = start_idx
            contain_zero = False
            while idx <len(field) and (pd.notna(field.iloc[idx][f'{th}碼'])):
                # print(type(field.iloc[idx][f'{th}碼']))

                if isinstance(field.iloc[idx][f'{th}碼'], np.floating):
                    code = str(int(field.iloc[idx][f'{th}碼']))
                else:
                    code = str(field.iloc[idx][f'{th}碼'])

                if code == '0' and not contain_zero:
                    contain_zero = True
                elif code == '0' and  contain_zero:
                    break

                group.append({
                    'code': code,
                    'name': field.iloc[idx][f'{th}碼名稱'],
                    'idx': idx,
                    'digit': th,
                })
                continue_lis.append(idx)
                idx += 1
            group_info.append({
                'start_idx': start_idx,
                'group': group
            })

    if len(group_info) == 0:
      return group_info

    for i, group in enumerate(group_info[:-1]):
        group_info[i]['end_idx'] = group_info[i+1]['start_idx']-1
    group_info[-1]['end_idx'] = 999

    return group_info

def cross_map(chapter, ml, mr):
    links = []
    for il in ml:
        for ir in mr:
            links.append([chapter, il['idx'], il['digit'], il['code'], il['name'], ir['idx'], ir['digit'], ir['code'], ir['name']])
    return links

def get_link(df, code, col1, col2, exam=False):
    if exam:
        print('========================')
    info_l = get_group(df, col1)
    info_r = get_group(df, col2)
    while len(info_r)==0 and col2 <= 9:
      col2 += 1
      info_r = get_group(df, col2)

    if len(info_l)==0 or col2 >= 10:
      return []

    gp_idx = 0
    links = []

    for g in info_l:
        if exam:
            print(f'''left : {g['start_idx']} ~ {g['end_idx']}''')
        map_left = g['group']
        map_idx = g['end_idx']

        map_right = info_r[gp_idx]['group']
        tmp_idx = gp_idx
        while tmp_idx+1 < len(info_r) and info_r[tmp_idx+1]['end_idx'] <= map_idx:
            map_right +=  info_r[tmp_idx+1]['group']
            tmp_idx += 1

        if exam:
            print(f'''right : {info_r[gp_idx]['start_idx']} ~ {info_r[tmp_idx]['end_idx']}''')

        new_links = cross_map(code, map_left, map_right)
        if exam:
            print(len(new_links))
        links += new_links
        if map_idx == info_r[tmp_idx]['end_idx']:
            gp_idx = tmp_idx+1
    # print(len(links))
    return links

def get_head_link(df, code, name, exam=False):

    info_r = get_group(df, 6)
    map_right = []
    for g in info_r:
        map_right +=  g['group']
    map_left = [{
        'idx': 0,
        'digit': 5,
        'name': name,
        'code': code,
    }]
    links = cross_map(code, map_left, map_right)
    if exam:
        print(len(links))
    return links

def map_link(infile, outfile, exam=False, return_df=False):

    df = pd.read_excel(infile, skiprows=[0], names=colnames)
    field = df[['章碼', '章名']]
    code = '{:05}'.format(int(field['章碼'][0]))
    name = field['章名'][0]

    links = []
    links += get_head_link(df, code, name, exam=exam)
    links += get_link(df, code, 6, 7, exam=exam)
    links += get_link(df, code, 7, 8, exam=exam)
    links += get_link(df, code, 8, 9, exam=exam)

    df_out = pd.DataFrame(links, columns =['Chapter', 'Row', 'Digit', 'Code', 'Name', 'ChildRow', 'ChildDigit', 'ChildCode', 'ChildName'])
    if return_df:
      return df_out
    df_out.to_csv(outfile, index=False, encoding='utf-8-sig')

def parse_element(infile, outfile, return_df=False):
    df = pd.read_excel(infile, skiprows=[0], names=colnames)
    df_trans = pd.DataFrame(columns=['code', 'name'])

    element_data = []
    code, name = get_field_code(df)
    element_data.append([code, 0, 5, 'FieldCode', name])

    cols = get_culumns(df)
    for i, col in enumerate(cols):
        element_data.append([code, 0, i + 6, 'Column', col])

    append_items(df, code, element_data)
    df_out = pd.DataFrame(element_data, columns =['Chapter', 'Row', 'Digit', 'Code', 'Name'])

    if return_df:
        return df_out

    if outfile.endswith('csv'):
        df_out.to_csv(outfile, index=False, encoding='utf-8-sig')
    elif outfile.endswith('xlsx'):
        df_out.to_excel(outfile, index=False)

# %%
import os
all_xlsx = []
for subdir, dirs, files in os.walk('/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES'):
    for file in files:
        filepath = subdir + os.sep + file
        if filepath.endswith(".xls") or filepath.endswith(".xlsx"):
            all_xlsx.append(filepath)

print(f"get total {len(all_xlsx)} file")
# Out:
# get total 854 file

# %%
import pandas as pd
import numpy as np

# Suppress chained assignment warnings
pd.set_option('mode.chained_assignment', None)

# Column names for data processing
COLUMN_NAMES = ['Unnamed:0', '章碼', '章名', '6碼', '6碼名稱', '7碼', '7碼名稱', '8碼', '8碼名稱', '9碼',
                '9碼名稱', '10碼', '10碼名稱', '備註']

def extract_field_info(df):
    """Extracts the chapter code and name from the dataframe."""
    code = f"{int(df['章碼'][0]):05}"
    name = df['章名'][0]
    return code, name

def extract_column_headers(df):
    """Extracts column headers for codes from 6碼名稱 to 10碼名稱."""
    return [df[f'{i}碼名稱'][0] for i in range(6, 11)]

def parse_code(value):
    """Converts a numerical value to string format, ensuring integer representation if applicable."""
    if isinstance(value, (np.floating, float)):
        return str(int(value))
    return str(value)

def append_items(df, code, records):
    """Appends item information to the records list."""
    for i in range(6, 11):
        field_data = df.iloc[1:][[f'{i}碼', f'{i}碼名稱']].dropna(subset=[f'{i}碼'])
        field_data[f'{i}碼名稱'] = field_data[f'{i}碼名稱'].fillna('')

        for index, row in field_data.iterrows():
            records.append([code, index, i, parse_code(row[f'{i}碼']), row[f'{i}碼名稱']])

def extract_groups(df, digit):
    """Extracts groups of codes based on the given digit level."""
    field = df[[f'{digit}碼', f'{digit}碼名稱']]
    groups, skip_indices = [], set()

    for i, row in field.iterrows():
        if i in skip_indices or pd.isna(row[f'{digit}碼']):
            continue

        group, idx, has_zero = [], i, False
        while idx < len(field) and pd.notna(field.iloc[idx][f'{digit}碼']):
            code = parse_code(field.iloc[idx][f'{digit}碼'])

            if code == '0':
                if has_zero:
                    break
                has_zero = True

            group.append({'code': code, 'name': field.iloc[idx][f'{digit}碼名稱'], 'idx': idx, 'digit': digit})
            skip_indices.add(idx)
            idx += 1

        groups.append({'start_idx': i, 'group': group})

    for i in range(len(groups) - 1):
        groups[i]['end_idx'] = groups[i + 1]['start_idx'] - 1
    if groups:
        groups[-1]['end_idx'] = len(field) - 1

    return groups

def cross_map(chapter, left_group, right_group):
    """Creates mappings between left and right code groups."""
    return [
        [chapter, l['idx'], l['digit'], l['code'], l['name'], r['idx'], r['digit'], r['code'], r['name']]
        for l in left_group for r in right_group
    ]

def generate_links(df, code, left_digit, right_digit, verbose=False):
    """Generates linked mapping between two digit levels."""
    left_groups, right_groups = extract_groups(df, left_digit), extract_groups(df, right_digit)
    while not right_groups and right_digit <= 9:
        right_digit += 1
        right_groups = extract_groups(df, right_digit)

    if not left_groups or right_digit >= 10:
        return []

    links, right_idx = [], 0
    for left_group in left_groups:
        map_left = left_group['group']
        map_right = right_groups[right_idx]['group']
        tmp_idx = right_idx

        while tmp_idx + 1 < len(right_groups) and right_groups[tmp_idx + 1]['end_idx'] <= left_group['end_idx']:
            map_right += right_groups[tmp_idx + 1]['group']
            tmp_idx += 1

        links.extend(cross_map(code, map_left, map_right))
        if left_group['end_idx'] == right_groups[tmp_idx]['end_idx']:
            right_idx = tmp_idx + 1

    return links

def generate_head_links(df, code, name):
    """Generates top-level links for the field code."""
    right_groups = extract_groups(df, 6)
    map_right = [item for group in right_groups for item in group['group']]
    map_left = [{'idx': 0, 'digit': 5, 'name': name, 'code': code}]
    return cross_map(code, map_left, map_right)

def process_mapping(input_file, output_file, verbose=False, return_df=False):
    """Processes the mapping of codes from an input file and writes to an output file."""
    df = pd.read_excel(input_file, skiprows=[0], names=COLUMN_NAMES)
    code, name = extract_field_info(df)

    links = generate_head_links(df, code, name)
    for left, right in [(6, 7), (7, 8), (8, 9)]:
        links += generate_links(df, code, left, right, verbose)

    df_out = pd.DataFrame(links, columns=['Chapter', 'Row', 'Digit', 'Code', 'Name', 'ChildRow', 'ChildDigit', 'ChildCode', 'ChildName'])
    if return_df:
        return df_out
    df_out.to_csv(output_file, index=False, encoding='utf-8-sig')

def process_elements(input_file, output_file, return_df=False):
    """Processes elements from the input file and writes to the output file."""
    df = pd.read_excel(input_file, skiprows=[0], names=COLUMN_NAMES)
    code, name = extract_field_info(df)
    elements = [[code, 0, 5, 'FieldCode', name]]

    for i, col in enumerate(extract_column_headers(df), start=6):
        elements.append([code, 0, i, 'Column', col])
    print(elements)
    assert False

    append_items(df, code, elements)
    df_out = pd.DataFrame(elements, columns=['Chapter', 'Row', 'Digit', 'Code', 'Name'])

    if return_df:
        return df_out

    if output_file.endswith('csv'):
        df_out.to_csv(output_file, index=False, encoding='utf-8-sig')
    elif output_file.endswith('xlsx'):
        df_out.to_excel(output_file, index=False)

# %%
test_file = '/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02983_codev20.xls'
process_elements(test_file, '', return_df=True)
# Out:
# [['02983', 0, 5, 'FieldCode', '機坪道肩之底層'], ['02983', 0, 6, 'Column', '材料'], ['02983', 0, 7, 'Column', '總厚度'], ['02983', 0, 8, 'Column', nan], ['02983', 0, 9, 'Column', nan], ['02983', 0, 10, 'Column', '估價用單位']]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-48033033b451> in <cell line: 0>()
#       1 test_file = '/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02983_codev20.xls'
# ----> 2 process_elements(test_file, '', return_df=True)
#
# <ipython-input-12-28b33bc8bff4> in process_elements(input_file, output_file, return_df)
#     128         elements.append([code, 0, i, 'Column', col])
#     129     print(elements)
# --> 130     assert False
#     131
#     132     append_items(df, code, elements)
#
# AssertionError:

# %%
df_element = []
df_link = []
success_file = []
for f in all_xlsx:
  try:
    df_element.append(parse_element(f, '', return_df=True))
    df_link.append(map_link(f, '', exam=False, return_df=True))
    success_file.append(f)
  except KeyError:
    print("KEY ERROR : ", f)
  except:
    print("OTHER ERROR : ", f)
# Out:
#    Unnamed:0      章碼       章名   6碼    6碼名稱   7碼   7碼名稱   8碼  8碼名稱   9碼  9碼名稱  \
# 0        NaN  2983.0  機坪道肩之底層  NaN      材料  NaN    總厚度  NaN   NaN  NaN   NaN
# 1        NaN     NaN      NaN  0.0     NaN  0.0    NaN  0.0   NaN  0.0   NaN
# 2        NaN     NaN      NaN  1.0  碎石級配粒料  1.0  200mm  NaN   NaN  NaN   NaN
# 3        NaN     NaN      NaN  NaN     NaN  2.0  250mm  NaN   NaN  NaN   NaN
# 4        NaN     NaN      NaN  NaN     NaN  3.0  300mm  NaN   NaN  NaN   NaN
#
#    10碼  10碼名稱        備註
# 0  NaN  估價用單位       NaN
# 1  1.0      M  0:不分類時使用
# 2  2.0     M2       NaN
# 3  3.0     M3       NaN
# 4  4.0      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02983_codev20.xls
#   Unnamed:0      章碼            章名   6碼 6碼名稱   7碼    7碼名稱   8碼  8碼名稱   9碼  \
# 0         M  2054.0  借土區及採石場之材料生產  NaN  大類別  NaN      土壤  NaN   NaN  NaN
# 1       NaN     NaN           NaN  0.0  NaN  0.0     NaN  0.0   NaN  0.0
# 2       NaN     NaN           NaN  1.0  借土區  1.0  粒料碎石篩選  NaN   NaN  NaN
# 3       NaN     NaN           NaN  2.0  採石場  2.0    粒料儲存  NaN   NaN  NaN
# 4       NaN     NaN           NaN  NaN  NaN  NaN     NaN  NaN   NaN  NaN
#
#    9碼名稱  10碼  10碼名稱        備註
# 0   NaN  NaN  估價用單位       NaN
# 1   NaN  1.0      M  0:不分類時使用
# 2   NaN  2.0     M2       NaN
# 3   NaN  3.0     M3       NaN
# 4   NaN  4.0      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02054_codev30.xls
#    Unnamed:0      章碼          章名   6碼          6碼名稱   7碼          7碼名稱   8碼  \
# 0        NaN  2120.0  廢棄物運離工地及棄置  NaN            運距  NaN          處理場所  NaN
# 1        NaN     NaN         NaN  0.0           NaN  0.0           NaN  0.0
# 2        NaN     NaN         NaN  1.0       運距＜30km  1.0    業主指定收容處理場所  NaN
# 3        NaN     NaN         NaN  2.0  30km≦運距＜60km  2.0  廠商自覓合法收容處理場所  NaN
# 4        NaN     NaN         NaN  3.0  60km≦運距＜90km  NaN           NaN  NaN
#
#    8碼名稱   9碼        9碼名稱  10碼  10碼名稱        備註
# 0   NaN  NaN         NaN  NaN  估價用單位       NaN
# 1   NaN  0.0         NaN    1      M  0:不分類時使用
# 2   NaN  1.0         人工費    2     M2       NaN
# 3   NaN  2.0       委外處理費    3     M3       NaN
# 4   NaN  3.0  一般廢棄物清運處理費    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02120_codev20.xlsx
#    Unnamed:0      章碼    章名   6碼   6碼名稱   7碼  7碼名稱   8碼   8碼名稱   9碼     9碼名稱  \
# 0        NaN  2220.0  工地拆除  NaN  機械或人工  NaN  拆除類別  NaN     類別  NaN    運費/其他
# 1        NaN     NaN   NaN  0.0    NaN    0   NaN    0    NaN    0      NaN
# 2        NaN     NaN   NaN  1.0   機械拆除    1  路面挖除    1  瀝青混凝土    1      含運費
# 3        NaN     NaN   NaN  2.0   人工拆除  NaN   NaN    2  水泥混凝土    2     未含運費
# 4        NaN     NaN   NaN  3.0   機械切割  NaN   NaN    3   砂石級配    3  含裝車未含運費
#
#    10碼  10碼名稱                     備註
# 0  NaN  估價用單位                    NaN
# 1    1      M               0:不分類時使用
# 2    2     M2                    NaN
# 3    3     M3  第9碼之「A 復舊費」限「5 人行道」使用
# 4    4      式                    NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02220_codev120.xls
#    Unnamed:0      章碼     章名   6碼  6碼名稱   7碼           7碼名稱   8碼   8碼名稱   9碼  \
# 0        NaN  2218.0  鑽探與取樣  NaN    地質  NaN       (孔向,孔深m)  NaN  取樣與試驗  NaN
# 1        NaN     NaN    NaN  0.0   NaN  0.0            NaN    0    NaN    0
# 2        NaN     NaN    NaN  1.0   土壤層  1.0    0≦垂直孔深＜100m    1   全程取樣    1
# 3        NaN     NaN    NaN  2.0  卵礫石層  2.0  100≦垂直孔深＜200m  NaN    NaN    2
# 4        NaN     NaN    NaN  3.0   軟岩層  3.0  200≦垂直孔深＜300m  NaN    NaN    3
#
#      9碼名稱  10碼  10碼名稱        備註
# 0      其他  NaN  估價用單位       NaN
# 1     NaN    1      M  0:不分類時使用
# 2    土層取樣    2     M2       NaN
# 3  卵礫石層取樣    3     M3       NaN
# 4    岩層取樣    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02218_codev70.xls
#    Unnamed:0      章碼     章名   6碼    6碼名稱   7碼     7碼名稱   8碼     8碼名稱   9碼  \
# 0        NaN  2231.0  清除及掘除  NaN  掘除平均厚度  NaN  清除範圍及其他  NaN     平均運距  NaN
# 1        NaN     NaN    NaN  0.0     NaN    0      NaN  0.0      NaN  0.0
# 2        NaN     NaN    NaN  1.0   t=5cm    1  廢棄物機具挖方  1.0  平均運距8km  1.0
# 3        NaN     NaN    NaN  2.0  t=10cm    2       雜草  NaN      NaN  2.0
# 4        NaN     NaN    NaN  3.0  t=15cm    3      高莖草  NaN      NaN  3.0
#
#            9碼名稱  10碼  10碼名稱        備註
# 0         砍伐面直徑  NaN  估價用單位       NaN
# 1           NaN    1      M  0:不分類時使用
# 2    砍伐面直徑≦29CM    2     M2       NaN
# 3  砍伐面直徑30~69CM    3     M3       NaN
# 4  砍伐面直徑70~99CM    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02231_codev60.xls
#    Unnamed:0      章碼    章名   6碼  6碼名稱   7碼 7碼名稱   8碼   8碼名稱   9碼  \
# 0        NaN  2230.0  工地清理  NaN   大類別  NaN  次類別  NaN    小類別  NaN
# 1        NaN     NaN   NaN    0   NaN    0  NaN    0    NaN  0.0
# 2        NaN     NaN   NaN    1    邊坡    1  平台溝    1     有蓋  1.0
# 3        NaN     NaN   NaN    2  排水設施    2   豎溝    2     無蓋  2.0
# 4        NaN     NaN   NaN  NaN   NaN    3  V型溝    3  寬度≦1m  3.0
#
#               9碼名稱  10碼  10碼名稱        備註
# 0               方式  NaN  估價用單位       NaN
# 1              NaN    1      M  0:不分類時使用
# 2               內側    2     M2       NaN
# 3               外側    3     M3       NaN
# 4  高壓洗滌(含洩水孔蓋版吊、放)    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02230_codev20.xlsx
#   Unnamed:0      章碼   章名   6碼 6碼名稱   7碼     7碼名稱   8碼     8碼名稱   9碼  9碼名稱  \
# 0         M  2240.0   袪水  NaN  大類別  NaN      次類別  NaN       深度  NaN    其他
# 1       NaN     NaN  NaN    0  NaN  0.0      NaN    0      NaN  0.0   NaN
# 2       NaN     NaN  NaN    1   點井  1.0    直徑5cm    1    深度＜6m  1.0   鑿孔費
# 3       NaN     NaN  NaN    2   深井  2.0  直徑7.5cm    2  6≦深度＜7m  2.0   操作費
# 4       NaN     NaN  NaN    C  抽水井  3.0   直徑10cm    3  7≦深度＜8m  3.0  防蝕處理
#
#    10碼  10碼名稱        備註
# 0  NaN  估價用單位       NaN
# 1    1      M  0：不分類時使用
# 2    2     M2       NaN
# 3    3     M3       NaN
# 4    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02240_codev60.xls
#    Unnamed:0      章碼         章名   6碼     6碼名稱   7碼   7碼名稱   8碼 8碼名稱   9碼  \
# 0        NaN  2252.0  公共管線系統之保護  NaN      大類別  NaN    次類別  NaN  NaN  NaN
# 1        NaN     NaN        NaN    0      NaN  0.0    NaN  0.0  NaN  0.0
# 2        NaN     NaN        NaN    1  電力系統及設備  1.0   臨時支撐  1.0  含吊裝  NaN
# 3        NaN     NaN        NaN    2  電信系統及設備  2.0   臨時遷移  NaN  NaN  NaN
# 4        NaN     NaN        NaN    3       油管  3.0  永久性遷移  NaN  NaN  NaN
#
#    9碼名稱  10碼  10碼名稱        備註
# 0   NaN  NaN  估價用單位       NaN
# 1   NaN    1      M  0：不分類時使用
# 2   NaN    2     M2       NaN
# 3   NaN    3     M3       NaN
# 4   NaN    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02252_codev40.xls
#   Unnamed:0      章碼         章名   6碼  6碼名稱   7碼 7碼名稱   8碼  8碼名稱   9碼  9碼名稱  \
# 0         M  2251.0  地下構造物保護灌漿  NaN   大類別  NaN       NaN   NaN  NaN   NaN
# 1       NaN     NaN        NaN    0   NaN    0  NaN  0.0   NaN  0.0   NaN
# 2       NaN     NaN        NaN    1  化學灌漿            NaN   NaN  NaN   NaN
# 3       NaN     NaN        NaN    2  水泥灌漿            NaN   NaN  NaN   NaN
# 4       NaN     NaN        NaN    A  採取水樣            NaN   NaN  NaN   NaN
#
#    10碼  10碼名稱        備註
# 0  NaN  估價用單位       NaN
# 1    1      M  0：不分類時使用
# 2    2     M2       NaN
# 3    3     M3  參考02341章
# 4    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02251_codev20.xls
#   Unnamed:0      章碼       章名   6碼 6碼名稱   7碼                       7碼名稱   8碼  \
# 0         M  2255.0  臨時擋土樁設施  NaN  大類別  NaN       規格：長度、厚度及寬度(鋼軌長度及間距)  NaN
# 1       NaN     NaN      NaN    0  NaN   00                        NaN  NaN
# 2       NaN     NaN      NaN    1  木板樁   27  (丙種，L=2.72m，t=7cm，W=25cm)  NaN
# 3       NaN     NaN      NaN  NaN  NaN   30   (丙種，L=3.0m，t=7cm，W=25cm)  NaN
# 4       NaN     NaN      NaN  NaN  NaN   36  (乙種，L=3.64m，t=8cm，W=25cm)  NaN
#
#   8碼名稱   9碼               9碼名稱  10碼  10碼名稱        備註
# 0  NaN  NaN                 施工  NaN  估價用單位       NaN
# 1  NaN    0                NaN    1      M  0:不分類時使用
# 2  NaN    1   (單邊水平長度，含擋土支撐系統)    2     M2  依金字塔形之順序
# 3  NaN    2  (單邊水平長度，未含擋土支撐系統)    3     M3    6、7、8碼
# 4  NaN    3                 打拔    4      式  依金字塔形之順序
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02255_codev100.xls
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02253_codev30.xls
#    Unnamed:0      章碼     章名   6碼  6碼名稱   7碼  7碼名稱   8碼  8碼名稱   9碼  9碼名稱  10碼  \
# 0        NaN  2257.0  鋼管樁托底  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 1        NaN     NaN    NaN  0.0   NaN  0.0   NaN  0.0   NaN  0.0   NaN  1.0
# 2        NaN     NaN    NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  2.0
# 3        NaN     NaN    NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  3.0
# 4        NaN     NaN    NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  4.0
#
#    10碼名稱                  備註
# 0  估價用單位            0:不分類時使用
# 1      M       CNS7934,A2114
# 2     M2  「開挖支撐及保護」依02260章規定
# 3     M3     「土方工作」依02300章規定
# 4      式       「基樁」依02451章規定
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02257_codev20.xls
#   Unnamed:0      章碼       章名   6碼    6碼名稱   7碼     7碼名稱   8碼    8碼名稱   9碼  \
# 0       NaN  2260.0  開挖支撐及保護  NaN    垂直支撐  NaN     水平支撐  NaN    監測系統  NaN
# 1       NaN     NaN      NaN    0     NaN    0      NaN  0.0     NaN  0.0
# 2               NaN      NaN    1      木樁    1   木材水平支撐  1.0   含監測系統  1.0
# 3       NaN     NaN      NaN    3     鋼軌樁    2  H型鋼水平支撐  2.0  未含監測系統  2.0
# 4       NaN     NaN      NaN    4  併排式鑽掘樁    3   鋼管水平支撐  3.0  安裝及拆除費  3.0
#
#                                     9碼名稱  10碼  10碼名稱            備註
# 0                                     規格  NaN  估價用單位      0:不分類時使用
# 1                                    NaN    1      M      「結構用混凝土」
# 2  (第一層(H-300mm×300mm×10mm×15mm)，租金3.0月)    2     M2    依第03310章規定
# 3  (第一層(H-300mm×300mm×10mm×15mm)，租金4.0月)    3     M3         「連續壁」
# 4  (第二層(H-350mm×350mm×12mm×19mm)，租金2.0月)    4      式    依第02266章規定
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02260_codev60.xls
#    Unnamed:0      章碼   章名   6碼  6碼名稱   7碼  7碼名稱   8碼  8碼名稱   9碼       9碼名稱  \
# 0        NaN  2262.0   圍水  NaN   大類別  NaN   NaN  NaN   NaN  NaN         其他
# 1        NaN     NaN  NaN  0.0   NaN  0.0   NaN  0.0   NaN  0.0        NaN
# 2        NaN     NaN  NaN  1.0  砂包堆置  NaN   NaN  NaN   NaN  1.0   抽排水動力設備費
# 3        NaN     NaN  NaN  NaN   NaN  NaN   NaN  NaN   NaN  2.0      粗粒料運費
# 4        NaN     NaN  NaN  NaN   NaN  NaN   NaN  NaN   NaN  3.0  聚丙烯袋(含紮繩)
#
#    10碼  10碼名稱        備註
# 0  NaN  估價用單位       NaN
# 1    1      M  0:不分類時使用
# 2    2     M2       NaN
# 3    3     M3       NaN
# 4    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02262_codev10.xls
#    Unnamed:0      章碼   章名   6碼  6碼名稱   7碼         7碼名稱   8碼    8碼名稱   9碼  \
# 0        NaN  2266.0  連續壁  NaN   大類別  NaN           地質  NaN       寬  NaN
# 1        NaN     NaN  NaN  0.0   NaN    0          NaN    0     NaN    0
# 2        NaN     NaN  NaN  1.0  軟弱地質    1  (含導溝，厚45cm)    1  W=3.0m    1
# 3        NaN     NaN  NaN  2.0  砂土礫石    2  (含導溝，厚50cm)    2  W=3.5m    2
# 4        NaN     NaN  NaN  3.0    卵石    3  (含導溝，厚55cm)    3  W=4.0m    3
#
#     9碼名稱  10碼  10碼名稱        備註
# 0      深  NaN  估價用單位       NaN
# 1    NaN  1.0      M  0:不分類時使用
# 2   D=5m  2.0     M2       NaN
# 3  D=10m  3.0     M3      6、7碼
# 4  D=15m  4.0      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02266_codev40.xls
#    Unnamed:0      章碼              章名   6碼  6碼名稱   7碼  7碼名稱   8碼   8碼名稱   9碼  \
# 0        NaN  2291.0  工程施工前鄰近建築物現況調查  NaN   NaN  NaN   NaN  NaN    NaN  NaN
# 1        NaN     NaN             NaN  0.0   NaN  0.0   NaN  0.0    NaN  0.0
# 2        NaN     NaN             NaN  NaN   NaN  NaN   NaN  1.0  排水口調查  1.0
# 3        NaN     NaN             NaN  NaN   NaN  NaN   NaN  NaN    NaN  2.0
# 4        NaN     NaN             NaN  NaN   NaN  NaN   NaN  NaN    NaN  3.0
#
#   9碼名稱  10碼  10碼名稱        備註
# 0   項目  NaN  估價用單位       NaN
# 1  NaN    1      M  0：不分類時使用
# 2   調查    2     M2       NaN
# 3   測量    3     M3       NaN
# 4   攝影    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02291_codev40.xls
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02292_codev50.xls
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02300_codev90.xls
#    Unnamed:0      章碼      章名   6碼  6碼名稱   7碼          7碼名稱   8碼  8碼名稱   9碼  \
# 0        NaN  2308.0  地下廠房開挖  NaN    地質  NaN     斷面(高x寬)m2  NaN   NaN  NaN
# 1        NaN     NaN     NaN  0.0   NaN  0.0           NaN  0.0   NaN  0.0
# 2        NaN     NaN     NaN  1.0    軟岩  1.0      斷面<200m2  NaN   NaN  NaN
# 3        NaN     NaN     NaN  2.0    硬岩  2.0  200≦斷面<300m2  NaN   NaN  NaN
# 4        NaN     NaN     NaN  3.0  複合地質  3.0  300≦斷面<400m2  NaN   NaN  NaN
#
#    9碼名稱  10碼  10碼名稱              備註
# 0   NaN  NaN  估價用單位             NaN
# 1   NaN  1.0      M        ０：不分類時使用
# 2   NaN  2.0     M2             參照：
# 3   NaN  3.0     M3  第02447章隧道計測及儀器
# 4   NaN  4.0      式             NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02308_codev20.xls
#    Unnamed:0      章碼    章名   6碼   6碼名稱   7碼  7碼名稱   8碼  8碼名稱   9碼  9碼名稱  10碼  \
# 0        NaN  2309.0  路幅整修  NaN     土質  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 1        NaN     NaN   NaN  0.0    NaN  0.0   NaN  0.0   NaN  0.0   NaN  1.0
# 2        NaN     NaN   NaN  1.0  土方層整修  NaN   NaN  NaN   NaN  NaN   NaN  2.0
# 3        NaN     NaN   NaN  2.0  礫石層整修  NaN   NaN  NaN   NaN  NaN   NaN  3.0
# 4        NaN     NaN   NaN  NaN    NaN  NaN   NaN  NaN   NaN  NaN   NaN  4.0
#
#    10碼名稱        備註
# 0  估價用單位  0:不分類時使用
# 1      M       NaN
# 2     M2       NaN
# 3     M3       NaN
# 4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02309_codev20.xls
#   Unnamed:0      章碼    章名   6碼   6碼名稱   7碼     7碼名稱   8碼  8碼名稱   9碼  9碼名稱  \
# 0         M  2314.0  壩體填築  NaN    大類別  NaN     壓實度%  NaN   NaN  NaN   NaN
# 1       NaN     NaN   NaN  0.0    NaN    0      NaN  0.0   NaN  0.0   NaN
# 2       NaN     NaN   NaN  1.0  防滲心層區    1  85%≦壓實度  NaN   NaN  NaN   NaN
# 3       NaN     NaN   NaN  2.0  上游殼層區    2  86%≦壓實度  NaN   NaN  NaN   NaN
# 4       NaN     NaN   NaN  3.0  下游殼層區    3  87%≦壓實度  NaN   NaN  NaN   NaN
#
#    10碼  10碼名稱        備註
# 0  NaN  估價用單位       NaN
# 1    1      M  0:不分類時使用
# 2    2     M2       NaN
# 3    3     M3       NaN
# 4    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02314_codev30.xls
#   Unnamed:0      章碼        章名   6碼  6碼名稱   7碼       7碼名稱   8碼  8碼名稱   9碼  \
# 0         M  2312.0  壩基礎開挖面處理  NaN  基礎地質  NaN  處理方式及結構形式  NaN   NaN  NaN
# 1       NaN     NaN       NaN  0.0   NaN  0.0        NaN  0.0   NaN  0.0
# 2       NaN     NaN       NaN  1.0  岩盤基礎  1.0    心層基礎面處理  NaN   NaN  NaN
# 3       NaN     NaN       NaN  NaN   NaN  2.0    心層破碎帶處理  NaN   NaN  NaN
# 4       NaN     NaN       NaN  NaN   NaN  3.0  上游殼層基礎面處理  NaN   NaN  NaN
#
#    9碼名稱  10碼  10碼名稱            備註
# 0   NaN  NaN  估價用單位      0:不分類時使用
# 1   NaN    1      M  依綱要規範第02312章
# 2   NaN    2     M2           NaN
# 3   NaN    3     M3           NaN
# 4   NaN    4      式           NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02312_codev20.xls
#    Unnamed:0      章碼     章名   6碼  6碼名稱   7碼       7碼名稱   8碼  \
# 0        NaN  2316.0  構造物開挖  NaN    地質  NaN        次類別  NaN
# 1        NaN     NaN    NaN    0   NaN    0        NaN    0
# 2        NaN     NaN    NaN    1  軟弱地質    1      深度＜5m    1
# 3        NaN     NaN    NaN    2  砂土礫石    2   5≦深度＜10m    2
# 4        NaN     NaN    NaN    3    卵石    3  10≦深度＜15m    3
#
#                           8碼名稱   9碼              9碼名稱  10碼  10碼名稱  \
# 0                          細類別  NaN             處理及其他  NaN  估價用單位
# 1                          NaN    0               NaN    1      M
# 2              (含抽排水，依設計圖說計價線)    1           含餘方近運利用    2     M2
# 3             (未含抽排水，依設計圖說計價線)    2  (含餘方遠運利用，指定他標工地)    3     M3
# 4  (含簡易擋土及抽排水，高速公路垂直計價線外側60cm)    3           含餘方遠運暫存    4      式
#
#                          備註
# 0                       NaN
# 1                  0:不分類時使用
# 2  有關試挖、點井等見第02209章、第02240章
# 3                       NaN
# 4             不適用材料見第02320章
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02316_codev80.xls
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02317_codev50.xlsx
#   Unnamed:0      章碼       章名   6碼  6碼名稱   7碼 7碼名稱   8碼        8碼名稱   9碼  \
# 0         M  2319.0  選擇性回填材料  NaN   大類別  NaN  次類別  NaN          運距  NaN
# 1       NaN     NaN      NaN  0.0   NaN    0  NaN    0         NaN    0
# 2       NaN     NaN      NaN  1.0  透水材料    1    砂    1      運距＜5km    1
# 3       NaN     NaN      NaN  NaN   NaN    2   礫石    2   5≦運距＜10km    2
# 4       NaN     NaN      NaN  NaN   NaN    3   碎石    3  10≦運距＜15km    3
#
#          9碼名稱  10碼  10碼名稱                 備註
# 0       粒徑及其他  NaN  估價用單位                NaN
# 1         NaN    1      M           0:不分類時使用
# 2    0≦粒徑＜5cm    2     M2  參考台北市政府工務局相關編碼原則表
# 3   5≦粒徑＜10cm    3     M3                NaN
# 4  10≦粒徑＜20cm    4      式                NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02319_codev100.xls
#    Unnamed:0      章碼    章名   6碼  6碼名稱   7碼         7碼名稱   8碼  8碼名稱   9碼  \
# 0        NaN  2318.0  渠道開挖  NaN    地質  NaN           深度  NaN   抽排水  NaN
# 1        NaN     NaN   NaN  0.0   NaN  0.0          NaN  0.0   NaN    0
# 2        NaN     NaN   NaN  1.0  軟弱地質  1.0      深度 < 1m  1.0   含抽水    1
# 3        NaN     NaN   NaN  2.0  砂土礫石  2.0  1 ≦ 深度 < 2m  2.0  未含抽水    2
# 4        NaN     NaN   NaN  3.0    卵石  3.0  2 ≦ 深度 < 3m  NaN   NaN    3
#
#        9碼名稱  10碼  10碼名稱        備註
# 0      餘方處理  NaN  估價用單位       NaN
# 1       NaN    1      M  0：不分類時使用
# 2   含餘方自行處理    2     M2       NaN
# 3  未含餘方自行處理    3     M3       NaN
# 4      近運利用    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02318_codev30.xls
#    Unnamed:0      章碼     章名   6碼  6碼名稱   7碼     7碼名稱   8碼       8碼名稱   9碼  \
# 0        NaN  2320.0  不適用材料  NaN   NaN  NaN     計價方式  NaN         運距  NaN
# 1        NaN     NaN    NaN  0.0   NaN  0.0      NaN  0.0        NaN  0.0
# 2        NaN     NaN    NaN  NaN   NaN  1.0  含運費(外棄)  1.0    運距1~5km  NaN
# 3        NaN     NaN    NaN  NaN   NaN  2.0     未含運費  2.0   運距5~10km  NaN
# 4        NaN     NaN    NaN  NaN   NaN  NaN      NaN  3.0  運距10~20km  NaN
#
#    9碼名稱  10碼  10碼名稱        備註
# 0   NaN  NaN  估價用單位       NaN
# 1   NaN    1      M  0：不分類時使用
# 2   NaN    2     M2       NaN
# 3   NaN    3     M3       NaN
# 4   NaN    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02320_codev30.xls
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02323_codev70.xls
#   Unnamed:0      章碼     章名   6碼     6碼名稱   7碼  7碼名稱   8碼  8碼名稱   9碼 9碼名稱  10碼  \
# 0         M  2324.0  土方測沉板  NaN       填高  NaN   NaN  NaN   NaN  NaN   其他  NaN
# 1       NaN     NaN    NaN  0.0      NaN  0.0   NaN  0.0   NaN  0.0  NaN    1
# 2       NaN     NaN    NaN  1.0    填高＜2m  NaN   NaN  NaN   NaN  1.0   設置    2
# 3       NaN     NaN    NaN  2.0  2≦填高＜4m  NaN   NaN  NaN   NaN  2.0   觀測    3
# 4       NaN     NaN    NaN  3.0  4≦填高＜6m  NaN   NaN  NaN   NaN  3.0   維護    4
#
#    10碼名稱        備註
# 0  估價用單位       NaN
# 1      M  0：不分類時使用
# 2     M2       NaN
# 3     M3       NaN
# 4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02324_codev20.xls
#    Unnamed:0      章碼   章名   6碼  6碼名稱   7碼          7碼名稱   8碼       8碼名稱   9碼  \
# 0        NaN  2325.0   浚挖  NaN    地質  NaN         處理及其他  NaN       棄方距離  NaN
# 1        NaN     NaN  NaN  0.0   NaN    0           NaN  0.0        NaN  0.0
# 2        NaN     NaN  NaN  1.0  砂土礫石    1   (陸拋，含回淤方處理)  1.0    運距1~5km  1.0
# 3        NaN     NaN  NaN  2.0    黏土    2  (陸拋，未含回淤方處理)  2.0   運距5~10km  2.0
# 4        NaN     NaN  NaN  3.0    卵石    3   (海拋，含回淤方處理)  3.0  運距10~20km  3.0
#
#    9碼名稱  10碼  10碼名稱        備註
# 0    其他  NaN  估價用單位       NaN
# 1   NaN    1      M  0:不分類時使用
# 2   含回填    2     M2       NaN
# 3   含運棄    3     M3       NaN
# 4  潛水伕組    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02325_codev40.xls
#    Unnamed:0      章碼   章名   6碼  6碼名稱   7碼    7碼名稱   8碼     8碼名稱   9碼  9碼名稱  \
# 0        NaN  2326.0   浚填  NaN   NaN  NaN     NaN  NaN      NaN  NaN   NaN
# 1        NaN     NaN  NaN  0.0   NaN  0.0     NaN  0.0      NaN  0.0   NaN
# 2        NaN     NaN  NaN  1.0  飛砂防治  1.0  覆蓋天然山料  1.0  厚度10cm   NaN   NaN
# 3        NaN     NaN  NaN  NaN   NaN  NaN     NaN  2.0   厚度15cm  NaN   NaN
# 4        NaN     NaN  NaN  NaN   NaN  NaN     NaN  3.0   厚度20cm  NaN   NaN
#
#    10碼  10碼名稱            備註
# 0  NaN  估價用單位           NaN
# 1    1      M      0:不分類時使用
# 2    2     M2  1.利用浚挖材料不予計價
# 3    3     M3           NaN
# 4    4      式           NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02326_codev20.xls
#    Unnamed:0      章碼       章名   6碼   6碼名稱   7碼             7碼名稱   8碼  \
# 0        NaN  2331.0  基地及路堤填築  NaN     材料  NaN              壓實度  NaN
# 1        NaN     NaN      NaN    0    NaN    0                     0
# 2        NaN     NaN      NaN    1  原材料回填    1       壓實度 < 85%     1
# 3        NaN     NaN      NaN    2     借土    2  85% ≦ 壓實度 < 90%    2
# 4        NaN     NaN      NaN    3    借石方    3  90% ≦ 壓實度 < 95%    3
#
#              8碼名稱   9碼     9碼名稱  10碼  10碼名稱        備註
# 0              運距  NaN  粒徑大小及其他  NaN  估價用單位       NaN
# 1                  0.0             1      M  0：不分類時使用
# 2        運距 < 5km  1.0  調整含水量處理    2     M2       NaN
# 3   5 ≦ 運距 < 10km  NaN      NaN    3     M3       NaN
# 4  10 ≦ 運距 < 20km  NaN      NaN    4      式       NaN
# OTHER ERROR :  /content/drive/MyDrive/軟體小組/資料庫/工程會編碼/rawPCCES/Code02-table/02331_codev40.xls

# %%
element_path = "/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/element.xlsx"
df = pd.read_excel(element_path)
df = df[df['Rank'] == 5]
df = df[df['Code'] != '0']
df = df.drop(columns=['Rank'])

df.head()
df.to_csv("/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/unit.csv", index=False, encoding="utf-8")
df.to_excel("/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/unit.xlsx", index=False)

# %%
df_path = "/content/drive/MyDrive/軟體小組/資料庫/工程會編碼/unit.xlsx"
df = pd.read_excel(df_path)
# 生成唯一键（拼接 Chapter 和 Code）
df["UniqueKey"] = df["Chapter"].astype(str) + "_" + df["Code"].astype(str)

# 找出重复的唯一键
duplicates = df[df.duplicated("UniqueKey", keep=False)]

for duplicate in duplicates.iterrows():
    print(duplicate)
# Out:
# (1288, Chapter             15511
# Code                    1
# Name         熱水供應量<50公升/時
# UniqueKey         15511_1
# Name: 1288, dtype: object)
# (1289, Chapter                     15511
# Code                            2
# Name         50公升/時≦熱水供應量<100公升/時
# UniqueKey                 15511_2
# Name: 1289, dtype: object)
# (1290, Chapter                      15511
# Code                             3
# Name         100公升/時≦熱水供應量<130公升/時
# UniqueKey                  15511_3
# Name: 1290, dtype: object)
# (1291, Chapter                      15511
# Code                             4
# Name         130公升/時≦熱水供應量<160公升/時
# UniqueKey                  15511_4
# Name: 1291, dtype: object)
# (1292, Chapter                      15511
# Code                             5
# Name         160公升/時≦熱水供應量<200公升/時
# UniqueKey                  15511_5
# Name: 1292, dtype: object)
# (1293, Chapter                      15511
# Code                             6
# Name         200公升/時≦熱水供應量<280公升/時
# UniqueKey                  15511_6
# Name: 1293, dtype: object)
# (1328, Chapter        15511
# Code               1
# Name             密閉式
# UniqueKey    15511_1
# Name: 1328, dtype: object)
# (1329, Chapter        15511
# Code               2
# Name             開放式
# UniqueKey    15511_2
# Name: 1329, dtype: object)
# (1330, Chapter           15511
# Code                  3
# Name         密閉式附PE保溫鋁皮
# UniqueKey       15511_3
# Name: 1330, dtype: object)
# (1331, Chapter           15511
# Code                  4
# Name         開放式附PE保溫鋁皮
# UniqueKey       15511_4
# Name: 1331, dtype: object)
# (1332, Chapter         15511
# Code                5
# Name         密閉式PU保溫桶
# UniqueKey     15511_5
# Name: 1332, dtype: object)
# (1333, Chapter         15511
# Code                6
# Name         開放式PU保溫桶
# UniqueKey     15511_6
# Name: 1333, dtype: object)
# (2435, Chapter        16291
# Code               1
# Name         0.3B0.1
# UniqueKey    16291_1
# Name: 2435, dtype: object)
# (2436, Chapter        16291
# Code               2
# Name         0.3B0.2
# UniqueKey    16291_2
# Name: 2436, dtype: object)
# (2437, Chapter        16291
# Code               3
# Name         0.3B0.5
# UniqueKey    16291_3
# Name: 2437, dtype: object)
# (2438, Chapter        16291
# Code               4
# Name         0.3B0.9
# UniqueKey    16291_4
# Name: 2438, dtype: object)
# (2439, Chapter        16291
# Code               5
# Name         0.3B1.8
# UniqueKey    16291_5
# Name: 2439, dtype: object)
# (2440, Chapter        16291
# Code               6
# Name         0.6B0.1
# UniqueKey    16291_6
# Name: 2440, dtype: object)
# (2441, Chapter        16291
# Code               7
# Name         0.6B0.2
# UniqueKey    16291_7
# Name: 2441, dtype: object)
# (2442, Chapter        16291
# Code               8
# Name         0.6B0.5
# UniqueKey    16291_8
# Name: 2442, dtype: object)
# (2443, Chapter        16291
# Code               9
# Name         0.6B0.9
# UniqueKey    16291_9
# Name: 2443, dtype: object)
# (2444, Chapter        16291
# Code               A
# Name         0.6B1.8
# UniqueKey    16291_A
# Name: 2444, dtype: object)
# (2445, Chapter        16291
# Code               B
# Name         1.2B0.1
# UniqueKey    16291_B
# Name: 2445, dtype: object)
# (2446, Chapter        16291
# Code               C
# Name         1.2B0.2
# UniqueKey    16291_C
# Name: 2446, dtype: object)
# (2447, Chapter        16291
# Code               D
# Name         1.2B0.5
# UniqueKey    16291_D
# Name: 2447, dtype: object)
# (2448, Chapter        16291
# Code               E
# Name         1.2B0.9
# UniqueKey    16291_E
# Name: 2448, dtype: object)
# (2449, Chapter        16291
# Code               F
# Name         1.2B1.8
# UniqueKey    16291_F
# Name: 2449, dtype: object)
# (2450, Chapter        16291
# Code               G
# Name             C10
# UniqueKey    16291_G
# Name: 2450, dtype: object)
# (2451, Chapter        16291
# Code               H
# Name             C20
# UniqueKey    16291_H
# Name: 2451, dtype: object)
# (2452, Chapter        16291
# Code               J
# Name             C50
# UniqueKey    16291_J
# Name: 2452, dtype: object)
# (2457, Chapter        16291
# Code               1
# Name            0.3W
# UniqueKey    16291_1
# Name: 2457, dtype: object)
# (2458, Chapter        16291
# Code               2
# Name            0.3X
# UniqueKey    16291_2
# Name: 2458, dtype: object)
# (2459, Chapter        16291
# Code               3
# Name            0.3Y
# UniqueKey    16291_3
# Name: 2459, dtype: object)
# (2460, Chapter        16291
# Code               4
# Name            0.3Z
# UniqueKey    16291_4
# Name: 2460, dtype: object)
# (2461, Chapter        16291
# Code               5
# Name           0.3ZZ
# UniqueKey    16291_5
# Name: 2461, dtype: object)
# (2462, Chapter        16291
# Code               6
# Name            0.3M
# UniqueKey    16291_6
# Name: 2462, dtype: object)
# (2463, Chapter        16291
# Code               7
# Name            0.6W
# UniqueKey    16291_7
# Name: 2463, dtype: object)
# (2464, Chapter        16291
# Code               8
# Name            0.6X
# UniqueKey    16291_8
# Name: 2464, dtype: object)
# (2465, Chapter        16291
# Code               9
# Name            0.6Y
# UniqueKey    16291_9
# Name: 2465, dtype: object)
# (2466, Chapter        16291
# Code               A
# Name            0.6Z
# UniqueKey    16291_A
# Name: 2466, dtype: object)
# (2467, Chapter        16291
# Code               B
# Name           0.6ZZ
# UniqueKey    16291_B
# Name: 2467, dtype: object)
# (2468, Chapter        16291
# Code               C
# Name            0.6M
# UniqueKey    16291_C
# Name: 2468, dtype: object)
# (2469, Chapter        16291
# Code               D
# Name            1.2W
# UniqueKey    16291_D
# Name: 2469, dtype: object)
# (2470, Chapter        16291
# Code               E
# Name            1.2X
# UniqueKey    16291_E
# Name: 2470, dtype: object)
# (2471, Chapter        16291
# Code               F
# Name            1.2Y
# UniqueKey    16291_F
# Name: 2471, dtype: object)
# (2472, Chapter        16291
# Code               G
# Name            1.2Z
# UniqueKey    16291_G
# Name: 2472, dtype: object)
# (2473, Chapter        16291
# Code               H
# Name           1.2ZZ
# UniqueKey    16291_H
# Name: 2473, dtype: object)
# (2474, Chapter        16291
# Code               J
# Name            1.2M
# UniqueKey    16291_J
# Name: 2474, dtype: object)
# (2475, Chapter        16291
# Code               1
# Name            50VA
# UniqueKey    16291_1
# Name: 2475, dtype: object)
# (2476, Chapter        16291
# Code               2
# Name           100VA
# UniqueKey    16291_2
# Name: 2476, dtype: object)
# (2477, Chapter        16291
# Code               3
# Name           200VA
# UniqueKey    16291_3
# Name: 2477, dtype: object)
# (2478, Chapter        16291
# Code               4
# Name           500VA
# UniqueKey    16291_4
# Name: 2478, dtype: object)
# (2479, Chapter        16291
# Code               5
# Name            1kVA
# UniqueKey    16291_5
# Name: 2479, dtype: object)
# (2480, Chapter        16291
# Code               6
# Name            3kVA
# UniqueKey    16291_6
# Name: 2480, dtype: object)
# (2481, Chapter        16291
# Code               7
# Name            5kVA
# UniqueKey    16291_7
# Name: 2481, dtype: object)
# (2482, Chapter        16291
# Code               8
# Name          7.5kVA
# UniqueKey    16291_8
# Name: 2482, dtype: object)
# (2483, Chapter        16291
# Code               9
# Name           10kVA
# UniqueKey    16291_9
# Name: 2483, dtype: object)
# (2484, Chapter         16291
# Code                1
# Name         準確度等級0.1
# UniqueKey     16291_1
# Name: 2484, dtype: object)
# (2485, Chapter         16291
# Code                2
# Name         準確度等級0.2
# UniqueKey     16291_2
# Name: 2485, dtype: object)
# (2486, Chapter         16291
# Code                3
# Name         準確度等級0.5
# UniqueKey     16291_3
# Name: 2486, dtype: object)
# (2487, Chapter         16291
# Code                4
# Name         準確度等級1.0
# UniqueKey     16291_4
# Name: 2487, dtype: object)
# (2488, Chapter         16291
# Code                5
# Name         準確度等級1.5
# UniqueKey     16291_5
# Name: 2488, dtype: object)
# (2489, Chapter         16291
# Code                6
# Name         準確度等級2.0
# UniqueKey     16291_6
# Name: 2489, dtype: object)
# (2490, Chapter         16291
# Code                7
# Name         準確度等級2.5
# UniqueKey     16291_7
# Name: 2490, dtype: object)
# (2491, Chapter         16291
# Code                8
# Name         準確度等級3.0
# UniqueKey     16291_8
# Name: 2491, dtype: object)
# (2492, Chapter         16291
# Code                9
# Name         準確度等級5.0
# UniqueKey     16291_9
# Name: 2492, dtype: object)
# (2645, Chapter        16451
# Code               1
# Name            30kA
# UniqueKey    16451_1
# Name: 2645, dtype: object)
# (2646, Chapter        16451
# Code               2
# Name            40kA
# UniqueKey    16451_2
# Name: 2646, dtype: object)
# (2647, Chapter        16451
# Code               3
# Name            45kA
# UniqueKey    16451_3
# Name: 2647, dtype: object)
# (2648, Chapter        16451
# Code               4
# Name            50kA
# UniqueKey    16451_4
# Name: 2648, dtype: object)
# (2649, Chapter        16451
# Code               5
# Name            60kA
# UniqueKey    16451_5
# Name: 2649, dtype: object)
# (2650, Chapter        16451
# Code               6
# Name            65kA
# UniqueKey    16451_6
# Name: 2650, dtype: object)
# (2651, Chapter        16451
# Code               7
# Name            75kA
# UniqueKey    16451_7
# Name: 2651, dtype: object)
# (2652, Chapter        16451
# Code               8
# Name           100kA
# UniqueKey    16451_8
# Name: 2652, dtype: object)
# (2653, Chapter        16451
# Code               9
# Name           120kA
# UniqueKey    16451_9
# Name: 2653, dtype: object)
# (2654, Chapter        16451
# Code               1
# Name           2.5kA
# UniqueKey    16451_1
# Name: 2654, dtype: object)
# (2655, Chapter        16451
# Code               2
# Name             5kA
# UniqueKey    16451_2
# Name: 2655, dtype: object)
# (2656, Chapter        16451
# Code               3
# Name           7.5kA
# UniqueKey    16451_3
# Name: 2656, dtype: object)
# (2657, Chapter        16451
# Code               4
# Name            10kA
# UniqueKey    16451_4
# Name: 2657, dtype: object)
# (2658, Chapter        16451
# Code               5
# Name            15kA
# UniqueKey    16451_5
# Name: 2658, dtype: object)
# (2659, Chapter        16451
# Code               6
# Name            18kA
# UniqueKey    16451_6
# Name: 2659, dtype: object)
# (2660, Chapter        16451
# Code               7
# Name            20kA
# UniqueKey    16451_7
# Name: 2660, dtype: object)
# (2661, Chapter        16451
# Code               8
# Name            22kA
# UniqueKey    16451_8
# Name: 2661, dtype: object)
# (2662, Chapter        16451
# Code               9
# Name            25kA
# UniqueKey    16451_9
# Name: 2662, dtype: object)
# (2697, Chapter        16452
# Code               1
# Name            30kA
# UniqueKey    16452_1
# Name: 2697, dtype: object)
# (2698, Chapter        16452
# Code               2
# Name            40kA
# UniqueKey    16452_2
# Name: 2698, dtype: object)
# (2699, Chapter        16452
# Code               3
# Name            45kA
# UniqueKey    16452_3
# Name: 2699, dtype: object)
# (2700, Chapter        16452
# Code               4
# Name            50kA
# UniqueKey    16452_4
# Name: 2700, dtype: object)
# (2701, Chapter        16452
# Code               5
# Name            60kA
# UniqueKey    16452_5
# Name: 2701, dtype: object)
# (2702, Chapter        16452
# Code               6
# Name            65kA
# UniqueKey    16452_6
# Name: 2702, dtype: object)
# (2703, Chapter        16452
# Code               7
# Name            75kA
# UniqueKey    16452_7
# Name: 2703, dtype: object)
# (2704, Chapter        16452
# Code               8
# Name           100kA
# UniqueKey    16452_8
# Name: 2704, dtype: object)
# (2705, Chapter        16452
# Code               9
# Name           120kA
# UniqueKey    16452_9
# Name: 2705, dtype: object)
# (2706, Chapter        16452
# Code               1
# Name           2.5kA
# UniqueKey    16452_1
# Name: 2706, dtype: object)
# (2707, Chapter        16452
# Code               2
# Name             5kA
# UniqueKey    16452_2
# Name: 2707, dtype: object)
# (2708, Chapter        16452
# Code               3
# Name           7.5kA
# UniqueKey    16452_3
# Name: 2708, dtype: object)
# (2709, Chapter        16452
# Code               4
# Name            10kA
# UniqueKey    16452_4
# Name: 2709, dtype: object)
# (2710, Chapter        16452
# Code               5
# Name            15kA
# UniqueKey    16452_5
# Name: 2710, dtype: object)
# (2711, Chapter        16452
# Code               6
# Name            18kA
# UniqueKey    16452_6
# Name: 2711, dtype: object)
# (2712, Chapter        16452
# Code               7
# Name            20kA
# UniqueKey    16452_7
# Name: 2712, dtype: object)
# (2713, Chapter        16452
# Code               8
# Name            22kA
# UniqueKey    16452_8
# Name: 2713, dtype: object)
# (2714, Chapter        16452
# Code               9
# Name            25kA
# UniqueKey    16452_9
# Name: 2714, dtype: object)
# (2807, Chapter        16529
# Code               1
# Name            110V
# UniqueKey    16529_1
# Name: 2807, dtype: object)
# (2808, Chapter        16529
# Code               2
# Name            220V
# UniqueKey    16529_2
# Name: 2808, dtype: object)
# (2809, Chapter        16529
# Code               3
# Name            277V
# UniqueKey    16529_3
# Name: 2809, dtype: object)
# (2810, Chapter        16529
# Code               1
# Name          熱浸鍍鋅鋼管
# UniqueKey    16529_1
# Name: 2810, dtype: object)
# (2811, Chapter        16529
# Code               2
# Name            油漆鋼管
# UniqueKey    16529_2
# Name: 2811, dtype: object)
# (2812, Chapter        16529
# Code               3
# Name            烤漆鋼管
# UniqueKey    16529_3
# Name: 2812, dtype: object)
# (2815, Chapter        16529
# Code               1
# Name          熱浸鍍鋅鋼板
# UniqueKey    16529_1
# Name: 2815, dtype: object)
# (2816, Chapter        16529
# Code               2
# Name            耐候鋼板
# UniqueKey    16529_2
# Name: 2816, dtype: object)
# (2817, Chapter        16529
# Code               1
# Name         1A/220V
# UniqueKey    16529_1
# Name: 2817, dtype: object)
# (2818, Chapter         16529
# Code                2
# Name         10A/220V
# UniqueKey     16529_2
# Name: 2818, dtype: object)
# (2819, Chapter        16529
# Code               3
# Name            220V
# UniqueKey    16529_3
# Name: 2819, dtype: object)
# (2820, Chapter        16529
# Code               1
# Name            110V
# UniqueKey    16529_1
# Name: 2820, dtype: object)
# (2821, Chapter        16529
# Code               2
# Name            220V
# UniqueKey    16529_2
# Name: 2821, dtype: object)
# (2836, Chapter          16551
# Code                 1
# Name         雙燈帽型直燈管1管
# UniqueKey      16551_1
# Name: 2836, dtype: object)
# (2837, Chapter          16551
# Code                 2
# Name         雙燈帽型直燈管2管
# UniqueKey      16551_2
# Name: 2837, dtype: object)
# (2838, Chapter          16551
# Code                 3
# Name         雙燈帽型直燈管3管
# UniqueKey      16551_3
# Name: 2838, dtype: object)
# (2839, Chapter          16551
# Code                 4
# Name         雙燈帽型直燈管4管
# UniqueKey      16551_4
# Name: 2839, dtype: object)
# (2840, Chapter           16551
# Code                  5
# Name         無燈帽版狀直條型1條
# UniqueKey       16551_5
# Name: 2840, dtype: object)
# (2841, Chapter           16551
# Code                  6
# Name         無燈帽版狀直條型2條
# UniqueKey       16551_6
# Name: 2841, dtype: object)
# (2842, Chapter           16551
# Code                  7
# Name         無燈帽版狀直條型3條
# UniqueKey       16551_7
# Name: 2842, dtype: object)
# (2843, Chapter           16551
# Code                  8
# Name         無燈帽版狀直條型4條
# UniqueKey       16551_8
# Name: 2843, dtype: object)
# (2844, Chapter        16551
# Code               9
# Name           E10燈頭
# UniqueKey    16551_9
# Name: 2844, dtype: object)
# (2845, Chapter        16551
# Code               A
# Name           E12燈頭
# UniqueKey    16551_A
# Name: 2845, dtype: object)
# (2849, Chapter        16551
# Code               1
# Name              A型
# UniqueKey    16551_1
# Name: 2849, dtype: object)
# (2850, Chapter        16551
# Code               2
# Name              B型
# UniqueKey    16551_2
# Name: 2850, dtype: object)
# (2851, Chapter        16551
# Code               3
# Name              C型
# UniqueKey    16551_3
# Name: 2851, dtype: object)
# (2852, Chapter        16551
# Code               4
# Name              D型
# UniqueKey    16551_4
# Name: 2852, dtype: object)
# (2853, Chapter        16551
# Code               5
# Name              E型
# UniqueKey    16551_5
# Name: 2853, dtype: object)
# (2854, Chapter        16551
# Code               6
# Name              F型
# UniqueKey    16551_6
# Name: 2854, dtype: object)
# (2855, Chapter        16551
# Code               7
# Name              G型
# UniqueKey    16551_7
# Name: 2855, dtype: object)
# (2856, Chapter        16551
# Code               8
# Name              H型
# UniqueKey    16551_8
# Name: 2856, dtype: object)
# (2857, Chapter        16551
# Code               9
# Name              I型
# UniqueKey    16551_9
# Name: 2857, dtype: object)
# (2858, Chapter        16551
# Code               A
# Name              J型
# UniqueKey    16551_A
# Name: 2858, dtype: object)
# (2859, Chapter        16551
# Code               1
# Name           E10燈頭
# UniqueKey    16551_1
# Name: 2859, dtype: object)
# (2860, Chapter        16551
# Code               2
# Name           E12燈頭
# UniqueKey    16551_2
# Name: 2860, dtype: object)
# (2861, Chapter        16551
# Code               3
# Name           E14燈頭
# UniqueKey    16551_3
# Name: 2861, dtype: object)
# (2862, Chapter        16551
# Code               4
# Name           E17燈頭
# UniqueKey    16551_4
# Name: 2862, dtype: object)
# (2863, Chapter        16551
# Code               5
# Name           E27燈頭
# UniqueKey    16551_5
# Name: 2863, dtype: object)
# (2864, Chapter        16551
# Code               6
# Name           E41燈頭
# UniqueKey    16551_6
# Name: 2864, dtype: object)
# (2865, Chapter        16551
# Code               1
# Name             T12
# UniqueKey    16551_1
# Name: 2865, dtype: object)
# (2866, Chapter        16551
# Code               2
# Name             T10
# UniqueKey    16551_2
# Name: 2866, dtype: object)
# (2867, Chapter        16551
# Code               3
# Name              T9
# UniqueKey    16551_3
# Name: 2867, dtype: object)
# (2868, Chapter        16551
# Code               4
# Name              T8
# UniqueKey    16551_4
# Name: 2868, dtype: object)
# (2869, Chapter        16551
# Code               5
# Name              T5
# UniqueKey    16551_5
# Name: 2869, dtype: object)
# (2870, Chapter        16551
# Code               1
# Name         T12燈管用
# UniqueKey    16551_1
# Name: 2870, dtype: object)
# (2871, Chapter        16551
# Code               2
# Name          T10燈管用
# UniqueKey    16551_2
# Name: 2871, dtype: object)
# (2872, Chapter        16551
# Code               3
# Name           T9燈管用
# UniqueKey    16551_3
# Name: 2872, dtype: object)
# (2873, Chapter        16551
# Code               4
# Name           T8燈管用
# UniqueKey    16551_4
# Name: 2873, dtype: object)
# (3059, Chapter        16132
# Code               1
# Name          厚1.8mm
# UniqueKey    16132_1
# Name: 3059, dtype: object)
# (3060, Chapter        16132
# Code               2
# Name          厚2.7mm
# UniqueKey    16132_2
# Name: 3060, dtype: object)
# (3061, Chapter        16132
# Code               3
# Name          厚3.1mm
# UniqueKey    16132_3
# Name: 3061, dtype: object)
# (3062, Chapter        16132
# Code               4
# Name          厚3.6mm
# UniqueKey    16132_4
# Name: 3062, dtype: object)
# (3063, Chapter        16132
# Code               1
# Name          厚1.8mm
# UniqueKey    16132_1
# Name: 3063, dtype: object)
# (3064, Chapter        16132
# Code               2
# Name          厚2.7mm
# UniqueKey    16132_2
# Name: 3064, dtype: object)
# (3065, Chapter        16132
# Code               3
# Name          厚3.1mm
# UniqueKey    16132_3
# Name: 3065, dtype: object)
# (3066, Chapter        16132
# Code               4
# Name          厚3.6mm
# UniqueKey    16132_4
# Name: 3066, dtype: object)
# (3073, Chapter          16525
# Code                 1
# Name         線徑55mm2以下
# UniqueKey      16525_1
# Name: 3073, dtype: object)
# (3074, Chapter          16525
# Code                 2
# Name         線徑55mm2以上
# UniqueKey      16525_2
# Name: 3074, dtype: object)
# (3075, Chapter            16525
# Code                   3
# Name         390mmx120mm
# UniqueKey        16525_3
# Name: 3075, dtype: object)
# (3076, Chapter          16525
# Code                 4
# Name         410x140mm
# UniqueKey      16525_4
# Name: 3076, dtype: object)
# (3077, Chapter          16525
# Code                 5
# Name         460x160mm
# UniqueKey      16525_5
# Name: 3077, dtype: object)
# (3078, Chapter        16525
# Code               A
# Name              1檔
# UniqueKey    16525_A
# Name: 3078, dtype: object)
# (3079, Chapter        16525
# Code               B
# Name              2檔
# UniqueKey    16525_B
# Name: 3079, dtype: object)
# (3080, Chapter        16525
# Code               C
# Name              3檔
# UniqueKey    16525_C
# Name: 3080, dtype: object)
# (3081, Chapter        16525
# Code               D
# Name            4~5檔
# UniqueKey    16525_D
# Name: 3081, dtype: object)
# (3082, Chapter        16525
# Code               E
# Name            6~7檔
# UniqueKey    16525_E
# Name: 3082, dtype: object)
# (3083, Chapter        16525
# Code               F
# Name           8~10檔
# UniqueKey    16525_F
# Name: 3083, dtype: object)
# (3084, Chapter        16525
# Code               G
# Name          11~13檔
# UniqueKey    16525_G
# Name: 3084, dtype: object)
# (3085, Chapter        16525
# Code               1
# Name              A型
# UniqueKey    16525_1
# Name: 3085, dtype: object)
# (3086, Chapter        16525
# Code               2
# Name              B型
# UniqueKey    16525_2
# Name: 3086, dtype: object)
# (3087, Chapter        16525
# Code               3
# Name              C型
# UniqueKey    16525_3
# Name: 3087, dtype: object)
# (3088, Chapter        16525
# Code               4
# Name              D型
# UniqueKey    16525_4
# Name: 3088, dtype: object)
# (3089, Chapter        16525
# Code               5
# Name              E型
# UniqueKey    16525_5
# Name: 3089, dtype: object)
# (3090, Chapter        16525
# Code               6
# Name              F型
# UniqueKey    16525_6
# Name: 3090, dtype: object)
# (3091, Chapter        16525
# Code               7
# Name              G型
# UniqueKey    16525_7
# Name: 3091, dtype: object)
# (3092, Chapter        16525
# Code               8
# Name              H型
# UniqueKey    16525_8
# Name: 3092, dtype: object)
# (3094, Chapter        16525
# Code               A
# Name              J型
# UniqueKey    16525_A
# Name: 3094, dtype: object)
# (3095, Chapter        16525
# Code               B
# Name              K型
# UniqueKey    16525_B
# Name: 3095, dtype: object)
# (3096, Chapter        16525
# Code               C
# Name              L型
# UniqueKey    16525_C
# Name: 3096, dtype: object)
# (3097, Chapter        16525
# Code               D
# Name              M型
# UniqueKey    16525_D
# Name: 3097, dtype: object)
# (3098, Chapter        16525
# Code               E
# Name              N型
# UniqueKey    16525_E
# Name: 3098, dtype: object)
# (3099, Chapter        16525
# Code               F
# Name              O型
# UniqueKey    16525_F
# Name: 3099, dtype: object)
# (3100, Chapter        16525
# Code               G
# Name              P型
# UniqueKey    16525_G
# Name: 3100, dtype: object)
# (3109, Chapter        16525
# Code               1
# Name            E-27
# UniqueKey    16525_1
# Name: 3109, dtype: object)
# (3110, Chapter        16525
# Code               2
# Name            E-40
# UniqueKey    16525_2
# Name: 3110, dtype: object)
# (3111, Chapter        16525
# Code               3
# Name            E-44
# UniqueKey    16525_3
# Name: 3111, dtype: object)
# (3112, Chapter        16525
# Code               1
# Name             埋入型
# UniqueKey    16525_1
# Name: 3112, dtype: object)
# (3113, Chapter        16525
# Code               2
# Name             預鑄型
# UniqueKey    16525_2
# Name: 3113, dtype: object)
# (3114, Chapter        16525
# Code               3
# Name              底盤
# UniqueKey    16525_3
# Name: 3114, dtype: object)
# (3115, Chapter         16525
# Code                4
# Name         (底盤，埋入型)
# UniqueKey     16525_4
# Name: 3115, dtype: object)
# (3116, Chapter        16525
# Code               1
# Name              A1
# UniqueKey    16525_1
# Name: 3116, dtype: object)
# (3117, Chapter        16525
# Code               2
# Name              A2
# UniqueKey    16525_2
# Name: 3117, dtype: object)
# (3118, Chapter        16525
# Code               3
# Name              A3
# UniqueKey    16525_3
# Name: 3118, dtype: object)
# (3119, Chapter        16525
# Code               4
# Name              A4
# UniqueKey    16525_4
# Name: 3119, dtype: object)
# (3120, Chapter        16525
# Code               5
# Name              A5
# UniqueKey    16525_5
# Name: 3120, dtype: object)
# (3121, Chapter        16525
# Code               6
# Name              A6
# UniqueKey    16525_6
# Name: 3121, dtype: object)
# (3122, Chapter        16525
# Code               7
# Name              A7
# UniqueKey    16525_7
# Name: 3122, dtype: object)
# (3123, Chapter        16525
# Code               8
# Name              A8
# UniqueKey    16525_8
# Name: 3123, dtype: object)
# (3124, Chapter        16525
# Code               1
# Name              B1
# UniqueKey    16525_1
# Name: 3124, dtype: object)
# (3125, Chapter        16525
# Code               2
# Name              B2
# UniqueKey    16525_2
# Name: 3125, dtype: object)
# (3126, Chapter        16525
# Code               3
# Name              B3
# UniqueKey    16525_3
# Name: 3126, dtype: object)
# (3127, Chapter        16525
# Code               4
# Name              B4
# UniqueKey    16525_4
# Name: 3127, dtype: object)
# (3128, Chapter        16525
# Code               5
# Name              B5
# UniqueKey    16525_5
# Name: 3128, dtype: object)
# (3129, Chapter        16525
# Code               6
# Name              B6
# UniqueKey    16525_6
# Name: 3129, dtype: object)
# (3130, Chapter        16525
# Code               1
# Name              C1
# UniqueKey    16525_1
# Name: 3130, dtype: object)
# (3131, Chapter        16525
# Code               2
# Name              C2
# UniqueKey    16525_2
# Name: 3131, dtype: object)
# (3132, Chapter        16525
# Code               3
# Name              C3
# UniqueKey    16525_3
# Name: 3132, dtype: object)
# (3133, Chapter        16525
# Code               4
# Name              C4
# UniqueKey    16525_4
# Name: 3133, dtype: object)
# (3134, Chapter        16525
# Code               5
# Name              C5
# UniqueKey    16525_5
# Name: 3134, dtype: object)
# (3135, Chapter        16525
# Code               6
# Name              C6
# UniqueKey    16525_6
# Name: 3135, dtype: object)
# (3136, Chapter        16525
# Code               1
# Name              D1
# UniqueKey    16525_1
# Name: 3136, dtype: object)
# (3137, Chapter        16525
# Code               2
# Name              D2
# UniqueKey    16525_2
# Name: 3137, dtype: object)
# (3138, Chapter        16525
# Code               1
# Name              E1
# UniqueKey    16525_1
# Name: 3138, dtype: object)
# (3139, Chapter        16525
# Code               2
# Name              E2
# UniqueKey    16525_2
# Name: 3139, dtype: object)
# (3140, Chapter        16525
# Code               3
# Name              E3
# UniqueKey    16525_3
# Name: 3140, dtype: object)
# (3141, Chapter        16525
# Code               1
# Name              F1
# UniqueKey    16525_1
# Name: 3141, dtype: object)
# (3142, Chapter        16525
# Code               1
# Name            委外作業
# UniqueKey    16525_1
# Name: 3142, dtype: object)
# (3143, Chapter            16525
# Code                   2
# Name         配合施工通報APP作業
# UniqueKey        16525_2
# Name: 3143, dtype: object)
# (4353, Chapter        2392
# Code              1
# Name              M
# UniqueKey    2392_1
# Name: 4353, dtype: object)
# (4354, Chapter        2392
# Code              2
# Name             M2
# UniqueKey    2392_2
# Name: 4354, dtype: object)
# (4356, Chapter        2392
# Code              4
# Name              式
# UniqueKey    2392_4
# Name: 4356, dtype: object)
# (4357, Chapter        2392
# Code              5
# Name              T
# UniqueKey    2392_5
# Name: 4357, dtype: object)
# (4360, Chapter        2392
# Code              8
# Name              組
# UniqueKey    2392_8
# Name: 4360, dtype: object)
# (4361, Chapter        2392
# Code              9
# Name             KG
# UniqueKey    2392_9
# Name: 4361, dtype: object)
# (4362, Chapter        2392
# Code              1
# Name              M
# UniqueKey    2392_1
# Name: 4362, dtype: object)
# (4363, Chapter        2392
# Code              8
# Name         套(含附件)
# UniqueKey    2392_8
# Name: 4363, dtype: object)
# (4364, Chapter         2392
# Code               9
# Name         套(未含附件)
# UniqueKey     2392_9
# Name: 4364, dtype: object)
# (4367, Chapter        2392
# Code              1
# Name           陸上施工
# UniqueKey    2392_1
# Name: 4367, dtype: object)
# (4368, Chapter        2392
# Code              2
# Name           水上施工
# UniqueKey    2392_2
# Name: 4368, dtype: object)
# (4369, Chapter        2392
# Code              4
# Name              式
# UniqueKey    2392_4
# Name: 4369, dtype: object)
# (4370, Chapter        2392
# Code              5
# Name              T
# UniqueKey    2392_5
# Name: 4370, dtype: object)
# (4371, Chapter        2392
# Code              8
# Name              塊
# UniqueKey    2392_8
# Name: 4371, dtype: object)
# (5003, Chapter        2532
# Code              1
# Name            含安裝
# UniqueKey    2532_1
# Name: 5003, dtype: object)
# (5004, Chapter        2532
# Code              1
# Name            附膠條
# UniqueKey    2532_1
# Name: 5004, dtype: object)
# (5007, Chapter                2532
# Code                      1
# Name         含污水專用附膠條鑄鐵人孔框蓋
# UniqueKey            2532_1
# Name: 5007, dtype: object)
# (5131, Chapter        2580
# Code              1
# Name           L=5m
# UniqueKey    2580_1
# Name: 5131, dtype: object)
# (5132, Chapter        2580
# Code              2
# Name         L=5.5m
# UniqueKey    2580_2
# Name: 5132, dtype: object)
# (5133, Chapter        2580
# Code              3
# Name           L=6m
# UniqueKey    2580_3
# Name: 5133, dtype: object)
# (5134, Chapter        2580
# Code              4
# Name         L=6.5m
# UniqueKey    2580_4
# Name: 5134, dtype: object)
# (5135, Chapter        2580
# Code              5
# Name           L=7m
# UniqueKey    2580_5
# Name: 5135, dtype: object)
# (5136, Chapter        2580
# Code              6
# Name         L=7.5m
# UniqueKey    2580_6
# Name: 5136, dtype: object)
# (5137, Chapter        2580
# Code              7
# Name           L=8m
# UniqueKey    2580_7
# Name: 5137, dtype: object)
# (5138, Chapter        2580
# Code              8
# Name         L=8.5m
# UniqueKey    2580_8
# Name: 5138, dtype: object)
# (5139, Chapter        2580
# Code              9
# Name           L=9m
# UniqueKey    2580_9
# Name: 5139, dtype: object)
# (5140, Chapter        2580
# Code              A
# Name         L=9.5m
# UniqueKey    2580_A
# Name: 5140, dtype: object)
# (5153, Chapter        2580
# Code              1
# Name              M
# UniqueKey    2580_1
# Name: 5153, dtype: object)
# (5154, Chapter        2580
# Code              2
# Name             M2
# UniqueKey    2580_2
# Name: 5154, dtype: object)
# (5155, Chapter        2580
# Code              3
# Name             M3
# UniqueKey    2580_3
# Name: 5155, dtype: object)
# (5156, Chapter        2580
# Code              4
# Name              式
# UniqueKey    2580_4
# Name: 5156, dtype: object)
# (5157, Chapter        2580
# Code              5
# Name              T
# UniqueKey    2580_5
# Name: 5157, dtype: object)
# (5158, Chapter        2580
# Code              6
# Name              只
# UniqueKey    2580_6
# Name: 5158, dtype: object)
# (5159, Chapter        2580
# Code              7
# Name              個
# UniqueKey    2580_7
# Name: 5159, dtype: object)
# (5160, Chapter        2580
# Code              8
# Name              組
# UniqueKey    2580_8
# Name: 5160, dtype: object)
# (5161, Chapter        2580
# Code              9
# Name             KG
# UniqueKey    2580_9
# Name: 5161, dtype: object)
# (5162, Chapter        2580
# Code              A
# Name              支
# UniqueKey    2580_A
# Name: 5162, dtype: object)
# (5695, Chapter                   2893
# Code                         1
# Name          2.5≦ L ＜3.5m
# UniqueKey               2893_1
# Name: 5695, dtype: object)
# (5696, Chapter               2893
# Code                     2
# Name          3.5≦ L ＜4.5m
# UniqueKey           2893_2
# Name: 5696, dtype: object)
# (5697, Chapter               2893
# Code                     3
# Name          4.5≦ L ＜5.5m
# UniqueKey           2893_3
# Name: 5697, dtype: object)
# (5698, Chapter               2893
# Code                     4
# Name          5.5≦ L ＜6.5m
# UniqueKey           2893_4
# Name: 5698, dtype: object)
# (5699, Chapter               2893
# Code                     5
# Name          6.5≦ L ＜7.5m
# UniqueKey           2893_5
# Name: 5699, dtype: object)
# (5700, Chapter               2893
# Code                     6
# Name          7.5≦ L ＜8.5m
# UniqueKey           2893_6
# Name: 5700, dtype: object)
# (5701, Chapter               2893
# Code                     7
# Name          8.5≦ L ＜9.5m
# UniqueKey           2893_7
# Name: 5701, dtype: object)
# (5702, Chapter               2893
# Code                     8
# Name         9.5≦ L ＜10.5m
# UniqueKey           2893_8
# Name: 5702, dtype: object)
# (5703, Chapter                2893
# Code                      9
# Name         10.5≦ L ＜11.5m
# UniqueKey            2893_9
# Name: 5703, dtype: object)
# (5704, Chapter                2893
# Code                      A
# Name         11.5≦ L ＜12.5m
# UniqueKey            2893_A
# Name: 5704, dtype: object)
# (5705, Chapter                2893
# Code                      B
# Name         12.5≦ L ＜13.5m
# UniqueKey            2893_B
# Name: 5705, dtype: object)
# (5706, Chapter        2893
# Code              C
# Name           1.2M
# UniqueKey    2893_C
# Name: 5706, dtype: object)
# (5720, Chapter                   2893
# Code                         1
# Name         (12P*2，25A以上)加絕緣蓋
# UniqueKey               2893_1
# Name: 5720, dtype: object)
# (5721, Chapter               2893
# Code                     1
# Name         (410*100*8mm)
# UniqueKey           2893_1
# Name: 5721, dtype: object)
# (5722, Chapter        2893
# Code              2
# Name            NaN
# UniqueKey    2893_2
# Name: 5722, dtype: object)
# (5723, Chapter        2893
# Code              1
# Name         D=20cm
# UniqueKey    2893_1
# Name: 5723, dtype: object)
# (5724, Chapter        2893
# Code              2
# Name         D=30cm
# UniqueKey    2893_2
# Name: 5724, dtype: object)
# (5725, Chapter           2893
# Code                 3
# Name         20cm*20cm
# UniqueKey       2893_3
# Name: 5725, dtype: object)
# (5726, Chapter           2893
# Code                 4
# Name         30cm*30cm
# UniqueKey       2893_4
# Name: 5726, dtype: object)
# (5727, Chapter        2893
# Code              1
# Name             4"
# UniqueKey    2893_1
# Name: 5727, dtype: object)
# (5728, Chapter        2893
# Code              2
# Name             6"
# UniqueKey    2893_2
# Name: 5728, dtype: object)
# (5729, Chapter        2893
# Code              3
# Name             8"
# UniqueKey    2893_3
# Name: 5729, dtype: object)
# (5730, Chapter        2893
# Code              4
# Name          6"及8"
# UniqueKey    2893_4
# Name: 5730, dtype: object)
# (5731, Chapter         2893
# Code               5
# Name         60*60cm
# UniqueKey     2893_5
# Name: 5731, dtype: object)
# (5732, Chapter         2893
# Code               6
# Name         90*90cm
# UniqueKey     2893_6
# Name: 5732, dtype: object)
# (5733, Chapter           2893
# Code                 7
# Name         100*100cm
# UniqueKey       2893_7
# Name: 5733, dtype: object)
# (5734, Chapter           2893
# Code                 8
# Name         120*120cm
# UniqueKey       2893_8
# Name: 5734, dtype: object)
# (5735, Chapter             2893
# Code                   9
# Name         (3/4"，65cm)
# UniqueKey         2893_9
# Name: 5735, dtype: object)
# (5736, Chapter                2893
# Code                      A
# Name         (1 1/4"，110cm)
# UniqueKey            2893_A
# Name: 5736, dtype: object)
# (5737, Chapter                2893
# Code                      B
# Name         (1 1/4"，130cm)
# UniqueKey            2893_B
# Name: 5737, dtype: object)
# (5738, Chapter               2893
# Code                     C
# Name         (含L=17.5cm螺帽)
# UniqueKey           2893_C
# Name: 5738, dtype: object)
# (5739, Chapter         2893
# Code               1
# Name         太陽能警示燈用
# UniqueKey     2893_1
# Name: 5739, dtype: object)
# (5740, Chapter            2893
# Code                  1
# Name         鋼管(厚6.0mm）
# UniqueKey        2893_1
# Name: 5740, dtype: object)
# (5741, Chapter          2893
# Code                2
# Name         (厚1.0mm）
# UniqueKey      2893_2
# Name: 5741, dtype: object)
# (5742, Chapter        2893
# Code              1
# Name           面層復舊
# UniqueKey    2893_1
# Name: 5742, dtype: object)
# (5743, Chapter        2893
# Code              2
# Name           面層回填
# UniqueKey    2893_2
# Name: 5743, dtype: object)
# (6175, Chapter        5654
# Code              1
# Name              M
# UniqueKey    5654_1
# Name: 6175, dtype: object)
# (6176, Chapter        5654
# Code              2
# Name             M2
# UniqueKey    5654_2
# Name: 6176, dtype: object)
# (6177, Chapter        5654
# Code              3
# Name             M3
# UniqueKey    5654_3
# Name: 6177, dtype: object)
# (6178, Chapter        5654
# Code              4
# Name              式
# UniqueKey    5654_4
# Name: 6178, dtype: object)
# (6179, Chapter        5654
# Code              5
# Name              T
# UniqueKey    5654_5
# Name: 6179, dtype: object)
# (6180, Chapter        5654
# Code              6
# Name              只
# UniqueKey    5654_6
# Name: 6180, dtype: object)
# (6181, Chapter        5654
# Code              7
# Name              個
# UniqueKey    5654_7
# Name: 6181, dtype: object)
# (6182, Chapter        5654
# Code              8
# Name              組
# UniqueKey    5654_8
# Name: 6182, dtype: object)
# (6183, Chapter        5654
# Code              9
# Name             KG
# UniqueKey    5654_9
# Name: 6183, dtype: object)
# (6184, Chapter        5654
# Code              1
# Name         L=35mm
# UniqueKey    5654_1
# Name: 6184, dtype: object)
# (6185, Chapter        5654
# Code              2
# Name         L=40mm
# UniqueKey    5654_2
# Name: 6185, dtype: object)
# (6186, Chapter        5654
# Code              3
# Name         L=45mm
# UniqueKey    5654_3
# Name: 6186, dtype: object)
# (6187, Chapter        5654
# Code              4
# Name         L=50mm
# UniqueKey    5654_4
# Name: 6187, dtype: object)
# (6188, Chapter        5654
# Code              5
# Name         L=55mm
# UniqueKey    5654_5
# Name: 6188, dtype: object)
# (6189, Chapter        5654
# Code              6
# Name         L=60mm
# UniqueKey    5654_6
# Name: 6189, dtype: object)
# (6190, Chapter        5654
# Code              7
# Name         L=65mm
# UniqueKey    5654_7
# Name: 6190, dtype: object)
# (6191, Chapter        5654
# Code              8
# Name         L=70mm
# UniqueKey    5654_8
# Name: 6191, dtype: object)
# (6192, Chapter        5654
# Code              9
# Name         L=80mm
# UniqueKey    5654_9
# Name: 6192, dtype: object)
# (6193, Chapter        5654
# Code              A
# Name         L=90mm
# UniqueKey    5654_A
# Name: 6193, dtype: object)
# (6194, Chapter         5654
# Code               B
# Name         L=100mm
# UniqueKey     5654_B
# Name: 6194, dtype: object)
# (6195, Chapter         5654
# Code               C
# Name         L=105mm
# UniqueKey     5654_C
# Name: 6195, dtype: object)
# (6196, Chapter         5654
# Code               D
# Name         L=110mm
# UniqueKey     5654_D
# Name: 6196, dtype: object)
# (6197, Chapter         5654
# Code               E
# Name         L=115mm
# UniqueKey     5654_E
# Name: 6197, dtype: object)
# (6198, Chapter         5654
# Code               F
# Name         L=120mm
# UniqueKey     5654_F
# Name: 6198, dtype: object)
# (6199, Chapter         5654
# Code               H
# Name         L=130mm
# UniqueKey     5654_H
# Name: 6199, dtype: object)
# (6200, Chapter         5654
# Code               J
# Name         L=140mm
# UniqueKey     5654_J
# Name: 6200, dtype: object)
# (6201, Chapter         5654
# Code               M
# Name         L=160mm
# UniqueKey     5654_M
# Name: 6201, dtype: object)
# (6203, Chapter        5654
# Code              5
# Name         L=55mm
# UniqueKey    5654_5
# Name: 6203, dtype: object)
# (6204, Chapter        5654
# Code              6
# Name         L=60mm
# UniqueKey    5654_6
# Name: 6204, dtype: object)
# (6205, Chapter        5654
# Code              7
# Name         L=65mm
# UniqueKey    5654_7
# Name: 6205, dtype: object)
# (6206, Chapter        5654
# Code              A
# Name         L=90mm
# UniqueKey    5654_A
# Name: 6206, dtype: object)
# (6207, Chapter         5654
# Code               B
# Name         L=100mm
# UniqueKey     5654_B
# Name: 6207, dtype: object)
# (6208, Chapter         5654
# Code               C
# Name         L=105mm
# UniqueKey     5654_C
# Name: 6208, dtype: object)
# (6209, Chapter         5654
# Code               E
# Name         L=115mm
# UniqueKey     5654_E
# Name: 6209, dtype: object)
# (6210, Chapter         5654
# Code               F
# Name         L=120mm
# UniqueKey     5654_F
# Name: 6210, dtype: object)
# (6211, Chapter         5654
# Code               H
# Name         L=130mm
# UniqueKey     5654_H
# Name: 6211, dtype: object)
# (6212, Chapter         5654
# Code               C
# Name         L=105mm
# UniqueKey     5654_C
# Name: 6212, dtype: object)
# (6213, Chapter         5654
# Code               D
# Name         L=110mm
# UniqueKey     5654_D
# Name: 6213, dtype: object)
# (6214, Chapter         5654
# Code               E
# Name         L=115mm
# UniqueKey     5654_E
# Name: 6214, dtype: object)
# (6215, Chapter         5654
# Code               F
# Name         L=120mm
# UniqueKey     5654_F
# Name: 6215, dtype: object)
# (6217, Chapter         5654
# Code               H
# Name         L=130mm
# UniqueKey     5654_H
# Name: 6217, dtype: object)
# (6218, Chapter         5654
# Code               J
# Name         L=140mm
# UniqueKey     5654_J
# Name: 6218, dtype: object)
# (6221, Chapter         5654
# Code               M
# Name         L=160mm
# UniqueKey     5654_M
# Name: 6221, dtype: object)
# (6224, Chapter        5654
# Code              8
# Name              組
# UniqueKey    5654_8
# Name: 6224, dtype: object)
# (6697, Chapter          8120
# Code                1
# Name         氣密性120等級
# UniqueKey      8120_1
# Name: 6697, dtype: object)
# (6698, Chapter         8120
# Code               2
# Name         氣密性30等級
# UniqueKey     8120_2
# Name: 6698, dtype: object)
# (6699, Chapter        8120
# Code              3
# Name         氣密性8等級
# UniqueKey    8120_3
# Name: 6699, dtype: object)
# (6700, Chapter        8120
# Code              4
# Name         氣密性2等級
# UniqueKey    8120_4
# Name: 6700, dtype: object)
# (6701, Chapter               8120
# Code                     1
# Name         (隔音性，Ts-25等級)
# UniqueKey           8120_1
# Name: 6701, dtype: object)
# (6702, Chapter               8120
# Code                     2
# Name         (隔音性，Ts-30等級)
# UniqueKey           8120_2
# Name: 6702, dtype: object)
# (6703, Chapter               8120
# Code                     3
# Name         (隔音性，Ts-35等級)
# UniqueKey           8120_3
# Name: 6703, dtype: object)
# (6704, Chapter               8120
# Code                     4
# Name         (隔音性，Ts-40等級)
# UniqueKey           8120_4
# Name: 6704, dtype: object)
# (6705, Chapter                         8120
# Code                               1
# Name         (隔熱性，熱阻0.25m2.h.℃/Kcal)
# UniqueKey                     8120_1
# Name: 6705, dtype: object)
# (6706, Chapter                         8120
# Code                               2
# Name         (隔熱性，熱阻0.29m2.h.℃/Kcal)
# UniqueKey                     8120_2
# Name: 6706, dtype: object)
# (6707, Chapter                         8120
# Code                               3
# Name         (隔熱性，熱阻0.33m2.h.℃/Kcal)
# UniqueKey                     8120_3
# Name: 6707, dtype: object)
# (6708, Chapter                         8120
# Code                               4
# Name         (隔熱性，熱阻0.40m2.h.℃/Kcal)
# UniqueKey                     8120_4
# Name: 6708, dtype: object)
# (6709, Chapter        8120
# Code              1
# Name           F30A
# UniqueKey    8120_1
# Name: 6709, dtype: object)
# (6710, Chapter        8120
# Code              2
# Name           F60A
# UniqueKey    8120_2
# Name: 6710, dtype: object)
# (6711, Chapter        8120
# Code              3
# Name          F120A
# UniqueKey    8120_3
# Name: 6711, dtype: object)
# (6712, Chapter        8120
# Code              4
# Name           F30B
# UniqueKey    8120_4
# Name: 6712, dtype: object)
# (6713, Chapter        8120
# Code              5
# Name           F60B
# UniqueKey    8120_5
# Name: 6713, dtype: object)
# (6714, Chapter        8120
# Code              6
# Name          F120B
# UniqueKey    8120_6
# Name: 6714, dtype: object)
# (6715, Chapter        8120
# Code              1
# Name         普通平板玻璃
# UniqueKey    8120_1
# Name: 6715, dtype: object)
# (6716, Chapter        8120
# Code              2
# Name           膠合玻璃
# UniqueKey    8120_2
# Name: 6716, dtype: object)
# (6717, Chapter        8120
# Code              3
# Name           強化玻璃
# UniqueKey    8120_3
# Name: 6717, dtype: object)
# (6718, Chapter        8120
# Code              4
# Name           壓花玻璃
# UniqueKey    8120_4
# Name: 6718, dtype: object)
# (6719, Chapter           8120
# Code                 5
# Name         浮式及磨光平板玻璃
# UniqueKey       8120_5
# Name: 6719, dtype: object)
# (6720, Chapter        8120
# Code              6
# Name           雙層玻璃
# UniqueKey    8120_6
# Name: 6720, dtype: object)
# (6725, Chapter          8120
# Code                1
# Name         氣密性120等級
# UniqueKey      8120_1
# Name: 6725, dtype: object)
# (6726, Chapter         8120
# Code               2
# Name         氣密性30等級
# UniqueKey     8120_2
# Name: 6726, dtype: object)
# (6727, Chapter        8120
# Code              3
# Name         氣密性8等級
# UniqueKey    8120_3
# Name: 6727, dtype: object)
# (6728, Chapter        8120
# Code              4
# Name         氣密性2等級
# UniqueKey    8120_4
# Name: 6728, dtype: object)
# (6729, Chapter          8110
# Code                1
# Name         氣密性120等級
# UniqueKey      8110_1
# Name: 6729, dtype: object)
# (6730, Chapter         8110
# Code               2
# Name         氣密性30等級
# UniqueKey     8110_2
# Name: 6730, dtype: object)
# (6731, Chapter        8110
# Code              3
# Name         氣密性8等級
# UniqueKey    8110_3
# Name: 6731, dtype: object)
# (6732, Chapter        8110
# Code              4
# Name         氣密性2等級
# UniqueKey    8110_4
# Name: 6732, dtype: object)
# (6733, Chapter        8110
# Code              5
# Name            含玻璃
# UniqueKey    8110_5
# Name: 6733, dtype: object)
# (6734, Chapter               8110
# Code                     1
# Name         (隔音性，Ts-25等級)
# UniqueKey           8110_1
# Name: 6734, dtype: object)
# (6735, Chapter               8110
# Code                     2
# Name         (隔音性，Ts-30等級)
# UniqueKey           8110_2
# Name: 6735, dtype: object)
# (6736, Chapter               8110
# Code                     3
# Name         (隔音性，Ts-35等級)
# UniqueKey           8110_3
# Name: 6736, dtype: object)
# (6737, Chapter               8110
# Code                     4
# Name         (隔音性，Ts-40等級)
# UniqueKey           8110_4
# Name: 6737, dtype: object)
# (6738, Chapter                         8110
# Code                               1
# Name         (隔熱性，熱阻0.25m2.h.℃/Kcal)
# UniqueKey                     8110_1
# Name: 6738, dtype: object)
# (6739, Chapter                         8110
# Code                               2
# Name         (隔熱性，熱阻0.29m3.h.℃/Kcal)
# UniqueKey                     8110_2
# Name: 6739, dtype: object)
# (6740, Chapter                         8110
# Code                               3
# Name         (隔熱性，熱阻0.33m4.h.℃/Kcal)
# UniqueKey                     8110_3
# Name: 6740, dtype: object)
# (6741, Chapter                         8110
# Code                               4
# Name         (隔熱性，熱阻0.40m5.h.℃/Kcal)
# UniqueKey                     8110_4
# Name: 6741, dtype: object)
# (6742, Chapter        8110
# Code              1
# Name           F30A
# UniqueKey    8110_1
# Name: 6742, dtype: object)
# (6743, Chapter        8110
# Code              2
# Name           F60A
# UniqueKey    8110_2
# Name: 6743, dtype: object)
# (6744, Chapter        8110
# Code              3
# Name          F120A
# UniqueKey    8110_3
# Name: 6744, dtype: object)
# (6745, Chapter        8110
# Code              4
# Name           F30B
# UniqueKey    8110_4
# Name: 6745, dtype: object)
# (6746, Chapter        8110
# Code              5
# Name           F60B
# UniqueKey    8110_5
# Name: 6746, dtype: object)
# (6750, Chapter        8110
# Code              1
# Name           烤漆選色
# UniqueKey    8110_1
# Name: 6750, dtype: object)
# (6751, Chapter           8110
# Code                 2
# Name         45DB，烤漆選色
# UniqueKey       8110_2
# Name: 6751, dtype: object)
# (6768, Chapter          8130
# Code                1
# Name         氣密性120等級
# UniqueKey      8130_1
# Name: 6768, dtype: object)
# (6769, Chapter         8130
# Code               2
# Name         氣密性30等級
# UniqueKey     8130_2
# Name: 6769, dtype: object)
# (6770, Chapter        8130
# Code              3
# Name         氣密性8等級
# UniqueKey    8130_3
# Name: 6770, dtype: object)
# (6771, Chapter        8130
# Code              4
# Name         氣密性2等級
# UniqueKey    8130_4
# Name: 6771, dtype: object)
# (6772, Chapter        8130
# Code              5
# Name            毛絲面
# UniqueKey    8130_5
# Name: 6772, dtype: object)
# (6773, Chapter        8130
# Code              6
# Name             亮面
# UniqueKey    8130_6
# Name: 6773, dtype: object)
# (6774, Chapter        8130
# Code              7
# Name             鏡面
# UniqueKey    8130_7
# Name: 6774, dtype: object)
# (6775, Chapter               8130
# Code                     1
# Name         (隔音性，Ts-25等級)
# UniqueKey           8130_1
# Name: 6775, dtype: object)
# (6776, Chapter               8130
# Code                     2
# Name         (隔音性，Ts-30等級)
# UniqueKey           8130_2
# Name: 6776, dtype: object)
# (6777, Chapter               8130
# Code                     3
# Name         (隔音性，Ts-35等級)
# UniqueKey           8130_3
# Name: 6777, dtype: object)
# (6778, Chapter               8130
# Code                     4
# Name         (隔音性，Ts-40等級)
# UniqueKey           8130_4
# Name: 6778, dtype: object)
# (6779, Chapter        8130
# Code              5
# Name            毛絲面
# UniqueKey    8130_5
# Name: 6779, dtype: object)
# (6780, Chapter        8130
# Code              6
# Name             亮面
# UniqueKey    8130_6
# Name: 6780, dtype: object)
# (6781, Chapter        8130
# Code              7
# Name             鏡面
# UniqueKey    8130_7
# Name: 6781, dtype: object)
# (6782, Chapter                         8130
# Code                               1
# Name         (隔熱性，熱阻0.25m2.h.℃/Kcal)
# UniqueKey                     8130_1
# Name: 6782, dtype: object)
# (6783, Chapter                         8130
# Code                               2
# Name         (隔熱性，熱阻0.29m3.h.℃/Kcal)
# UniqueKey                     8130_2
# Name: 6783, dtype: object)
# (6784, Chapter                         8130
# Code                               3
# Name         (隔熱性，熱阻0.33m4.h.℃/Kcal)
# UniqueKey                     8130_3
# Name: 6784, dtype: object)
# (6785, Chapter                         8130
# Code                               4
# Name         (隔熱性，熱阻0.40m5.h.℃/Kcal)
# UniqueKey                     8130_4
# Name: 6785, dtype: object)
# (6786, Chapter        8130
# Code              5
# Name            毛絲面
# UniqueKey    8130_5
# Name: 6786, dtype: object)
# (6787, Chapter        8130
# Code              6
# Name             亮面
# UniqueKey    8130_6
# Name: 6787, dtype: object)
# (6788, Chapter        8130
# Code              7
# Name             鏡面
# UniqueKey    8130_7
# Name: 6788, dtype: object)
# (6789, Chapter                  8130
# Code                        1
# Name         (A種防火門，30分鐘防火時效)
# UniqueKey              8130_1
# Name: 6789, dtype: object)
# (6790, Chapter                 8130
# Code                       2
# Name         (A種防火門，1小時防火時效)
# UniqueKey             8130_2
# Name: 6790, dtype: object)
# (6791, Chapter                 8130
# Code                       3
# Name         (A種防火門，2小時防火時效)
# UniqueKey             8130_3
# Name: 6791, dtype: object)
# (6792, Chapter                  8130
# Code                        4
# Name         (B種防火門，30分鐘防火時效)
# UniqueKey              8130_4
# Name: 6792, dtype: object)
# (6793, Chapter                 8130
# Code                       5
# Name         (B種防火門，1小時防火時效)
# UniqueKey             8130_5
# Name: 6793, dtype: object)
# (6794, Chapter                 8130
# Code                       6
# Name         (B種防火門，2小時防火時效)
# UniqueKey             8130_6
# Name: 6794, dtype: object)
# (6795, Chapter        8130
# Code              7
# Name            毛絲面
# UniqueKey    8130_7
# Name: 6795, dtype: object)
# (6796, Chapter        8130
# Code              8
# Name             亮面
# UniqueKey    8130_8
# Name: 6796, dtype: object)
# (6797, Chapter        8130
# Code              9
# Name             鏡面
# UniqueKey    8130_9
# Name: 6797, dtype: object)
# (6798, Chapter              8130
# Code                    1
# Name         （毛絲面，普通平板玻璃）
# UniqueKey          8130_1
# Name: 6798, dtype: object)
# (6799, Chapter            8130
# Code                  2
# Name         （毛絲面，膠合玻璃）
# UniqueKey        8130_2
# Name: 6799, dtype: object)
# (6800, Chapter            8130
# Code                  3
# Name         （毛絲面，強化玻璃）
# UniqueKey        8130_3
# Name: 6800, dtype: object)
# (6801, Chapter            8130
# Code                  4
# Name         （毛絲面，壓花玻璃）
# UniqueKey        8130_4
# Name: 6801, dtype: object)
# (6802, Chapter                 8130
# Code                       5
# Name         （毛絲面，浮式及磨光平板玻璃）
# UniqueKey             8130_5
# Name: 6802, dtype: object)
# (6803, Chapter            8130
# Code                  6
# Name         （毛絲面，雙層玻璃）
# UniqueKey        8130_6
# Name: 6803, dtype: object)
# (6804, Chapter               8130
# Code                     7
# Name         （毛絲面，普通鐵絲網玻璃）
# UniqueKey           8130_7
# Name: 6804, dtype: object)
# (6805, Chapter                8130
# Code                      8
# Name         （毛絲面，有色吸音平板玻璃）
# UniqueKey            8130_8
# Name: 6805, dtype: object)
# (6806, Chapter             8130
# Code                   9
# Name         （亮面，普通平板玻璃）
# UniqueKey         8130_9
# Name: 6806, dtype: object)
# (6822, Chapter              8210
# Code                    1
# Name         (不含材料供應，含工資)
# UniqueKey          8210_1
# Name: 6822, dtype: object)
# (6823, Chapter        8210
# Code              2
# Name           不銹鋼框
# UniqueKey    8210_2
# Name: 6823, dtype: object)
# (6824, Chapter        8210
# Code              3
# Name           烤漆鋼框
# UniqueKey    8210_3
# Name: 6824, dtype: object)
# (6827, Chapter        8210
# Code              1
# Name           尼龍紗網
# UniqueKey    8210_1
# Name: 6827, dtype: object)
# (6828, Chapter        8210
# Code              2
# Name          不銹鋼紗網
# UniqueKey    8210_2
# Name: 6828, dtype: object)
# (6829, Chapter        8210
# Code              3
# Name           玻纖紗網
# UniqueKey    8210_3
# Name: 6829, dtype: object)
# (7099, Chapter              8229
# Code                    1
# Name         (不含材料供應，含工資)
# UniqueKey          8229_1
# Name: 7099, dtype: object)
# (7100, Chapter        8229
# Code              1
# Name         普通平板玻璃
# UniqueKey    8229_1
# Name: 7100, dtype: object)
# (7101, Chapter        8229
# Code              2
# Name           膠合玻璃
# UniqueKey    8229_2
# Name: 7101, dtype: object)
# (7102, Chapter        8229
# Code              3
# Name           強化玻璃
# UniqueKey    8229_3
# Name: 7102, dtype: object)
# (7111, Chapter        8229
# Code              1
# Name           尼龍紗網
# UniqueKey    8229_1
# Name: 7111, dtype: object)
# (7112, Chapter        8229
# Code              2
# Name          不銹鋼紗網
# UniqueKey    8229_2
# Name: 7112, dtype: object)
# (7113, Chapter        8229
# Code              3
# Name           玻纖紗網
# UniqueKey    8229_3
# Name: 7113, dtype: object)
